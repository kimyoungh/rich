# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/rich/main/rich/
# Out:
# /content/drive/MyDrive/rich/main/rich

# %%
# !pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorboardX
#   Downloading tensorboardX-2.5.1-py2.py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 KB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from tensorboardX) (1.21.6)
# Requirement already satisfied: protobuf<=3.20.1,>=3.8.0 in /usr/local/lib/python3.8/dist-packages (from tensorboardX) (3.19.6)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.5.1

# %%
# !pip install ray
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ray
#   Downloading ray-2.2.0-cp38-cp38-manylinux2014_x86_64.whl (57.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 MB 29.6 MB/s eta 0:00:00
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.8/dist-packages (from ray) (3.19.6)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.8/dist-packages (from ray) (1.3.3)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.8/dist-packages (from ray) (4.3.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from ray) (3.9.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.8/dist-packages (from ray) (22.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from ray) (2.25.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from ray) (1.0.4)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.8/dist-packages (from ray) (1.3.1)
# Requirement already satisfied: grpcio>=1.32.0 in /usr/local/lib/python3.8/dist-packages (from ray) (1.51.1)
# Collecting virtualenv>=20.0.24
#   Downloading virtualenv-20.17.1-py3-none-any.whl (8.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 122.0 MB/s eta 0:00:00
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.8/dist-packages (from ray) (7.1.2)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.8/dist-packages (from ray) (1.21.6)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (from ray) (6.0)
# Requirement already satisfied: platformdirs<3,>=2.4 in /usr/local/lib/python3.8/dist-packages (from virtualenv>=20.0.24->ray) (2.6.2)
# Collecting distlib<1,>=0.3.6
#   Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.5/468.5 KB 48.3 MB/s eta 0:00:00
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema->ray) (0.19.3)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema->ray) (5.10.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->ray) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->ray) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->ray) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->ray) (2.10)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=1.4.0->jsonschema->ray) (3.11.0)
# Installing collected packages: distlib, virtualenv, ray
# Successfully installed distlib-0.3.6 ray-2.2.0 virtualenv-20.17.1

# %%
# !PYTHONPATH=./ python trainers/trading_bc_transformer2_train.py --epoch_size=10000 --pretrain_epoch_prob=0.5 --num_samples 1\
 --batch_size 2048 --valid_batch_size 512 --device cuda --lr 0.0001 --model_name trading_bc_transformer2
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Result for train_trader_59abf_00000:
#   date: 2023-01-24_15-12-32
#   done: false
#   experiment_id: 90ce3b741f3e4b32bbee2f7d57a651f4
#   hostname: ffed65665576
#   iterations_since_restore: 9740
#   loss: 0.9853218464066926
#   loss_act: 1.9247172464614628
#   loss_ud: 0.9853218464066926
#   node_ip: 172.28.0.12
#   pid: 2695
#   should_checkpoint: true
#   time_since_restore: 22835.948664188385
#   time_this_iter_s: 2.64798641204834
#   time_total_s: 22835.948664188385
#   timestamp: 1674573152
#   timesteps_since_restore: 0
#   training_iteration: 9740
#   trial_id: 59abf_00000
#   warmup_time: 0.0044901371002197266
#
# == Status ==
# Current time: 2023-01-24 15:12:35 (running for 06:20:41.61)
# Memory usage on this node: 5.5/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4096.000: -0.7689869808564197 | Iter 1024.000: -1.4568044934603481 | Iter 256.000: -1.622901872097414 | Iter 64.000: -1.6882946276147084 | Iter 16.000: -1.7309075328366605 | Iter 4.000: -2.6063361552626216 | Iter 1.000: -2.8950388669598555
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.89 GiB heap, 0.0/24.95 GiB objects
# Current best trial: 59abf_00000 with loss=0.9982662331381182 and parameters={'factor_num': 8, 'd_model': 64, 'dim_ff': 64, 'asset_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.3, 'tt_nhead': 4, 'tt_nlayers': 4, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KRW-XRP'}, 'action_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_name': 'trading_bc_transformer2', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_bc_transformer/train_dataset_5.pkl', 'epoch_size': 10000, 'batch_size': 2048, 'lr': 0.0001, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 512, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'sched_term': 5, 'lr_decay': 0.99, 'num_workers': 8, 'asset_idx': 0, 'pretrain_epoch_prob': 0.5, 'updown_coeff': 0.5}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_bc_transformer2/trading_bc_transformer2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+----------+-----------+------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |     loss |   loss_ud |   loss_act |
# |--------------------------+----------+------------------+--------+------------------+----------+-----------+------------|
# | train_trader_59abf_00000 | RUNNING  | 172.28.0.12:2695 |   9741 |          22838.6 | 0.998266 |  0.998266 |    1.93517 |
# +--------------------------+----------+------------------+--------+------------------+----------+-----------+------------+
#
#
# Result for train_trader_59abf_00000:
#   date: 2023-01-24_15-12-38
#   done: false
#   experiment_id: 90ce3b741f3e4b32bbee2f7d57a651f4
#   hostname: ffed65665576
#   iterations_since_restore: 9742
#   loss: 0.9825051755686132
#   loss_act: 1.9269886752426448
#   loss_ud: 0.9825051755686132
#   node_ip: 172.28.0.12
#   pid: 2695
#   should_checkpoint: true
#   time_since_restore: 22841.28480362892
#   time_this_iter_s: 2.670044422149658
#   time_total_s: 22841.28480362892
#   timestamp: 1674573158
#   timesteps_since_restore: 0
#   training_iteration: 9742
#   trial_id: 59abf_00000
#   warmup_time: 0.0044901371002197266
#
# == Status ==
# Current time: 2023-01-24 15:12:40 (running for 06:20:46.91)
# Memory usage on this node: 5.5/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4096.000: -0.7689869808564197 | Iter 1024.000: -1.4568044934603481 | Iter 256.000: -1.622901872097414 | Iter 64.000: -1.6882946276147084 | Iter 16.000: -1.7309075328366605 | Iter 4.000: -2.6063361552626216 | Iter 1.000: -2.8950388669598555
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.89 GiB heap, 0.0/24.95 GiB objects
# Current best trial: 59abf_00000 with loss=0.9952124762726957 and parameters={'factor_num': 8, 'd_model': 64, 'dim_ff': 64, 'asset_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.3, 'tt_nhead': 4, 'tt_nlayers': 4, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KRW-XRP'}, 'action_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_name': 'trading_bc_transformer2', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_bc_transformer/train_dataset_5.pkl', 'epoch_size': 10000, 'batch_size': 2048, 'lr': 0.0001, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 512, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'sched_term': 5, 'lr_decay': 0.99, 'num_workers': 8, 'asset_idx': 0, 'pretrain_epoch_prob': 0.5, 'updown_coeff': 0.5}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_bc_transformer2/trading_bc_transformer2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+----------+-----------+------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |     loss |   loss_ud |   loss_act |
# |--------------------------+----------+------------------+--------+------------------+----------+-----------+------------|
# | train_trader_59abf_00000 | RUNNING  | 172.28.0.12:2695 |   9743 |          22843.9 | 0.995212 |  0.995212 |    1.94139 |
# +--------------------------+----------+------------------+--------+------------------+----------+-----------+------------+
#
#
# Result for train_trader_59abf_00000:
#   date: 2023-01-24_15-12-43
#   done: false
#   experiment_id: 90ce3b741f3e4b32bbee2f7d57a651f4
#   hostname: ffed65665576
#   iterations_since_restore: 9744
#   loss: 0.9965573930785747
#   loss_act: 1.903504499060048
#   loss_ud: 0.9965573930785747
#   node_ip: 172.28.0.12
#   pid: 2695
#   should_checkpoint: true
#   time_since_restore: 22846.560573339462
#   time_this_iter_s: 2.647778272628784
#   time_total_s: 22846.560573339462
#   timestamp: 1674573163
#   timesteps_since_restore: 0
#   training_iteration: 9744
#   trial_id: 59abf_00000
#   warmup_time: 0.0044901371002197266
#
# == Status ==
# Current time: 2023-01-24 15:12:46 (running for 06:20:52.22)
# Memory usage on this node: 5.5/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4096.000: -0.7689869808564197 | Iter 1024.000: -1.4568044934603481 | Iter 256.000: -1.622901872097414 | Iter 64.000: -1.6882946276147084 | Iter 16.000: -1.7309075328366605 | Iter 4.000: -2.6063361552626216 | Iter 1.000: -2.8950388669598555
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.89 GiB heap, 0.0/24.95 GiB objects
# Current best trial: 59abf_00000 with loss=0.9878905694059661 and parameters={'factor_num': 8, 'd_model': 64, 'dim_ff': 64, 'asset_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.3, 'tt_nhead': 4, 'tt_nlayers': 4, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KRW-XRP'}, 'action_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_name': 'trading_bc_transformer2', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_bc_transformer/train_dataset_5.pkl', 'epoch_size': 10000, 'batch_size': 2048, 'lr': 0.0001, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 512, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'sched_term': 5, 'lr_decay': 0.99, 'num_workers': 8, 'asset_idx': 0, 'pretrain_epoch_prob': 0.5, 'updown_coeff': 0.5}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_bc_transformer2/trading_bc_transformer2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+----------+-----------+------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |     loss |   loss_ud |   loss_act |
# |--------------------------+----------+------------------+--------+------------------+----------+-----------+------------|
# | train_trader_59abf_00000 | RUNNING  | 172.28.0.12:2695 |   9745 |          22849.2 | 0.987891 |  0.987891 |    1.91624 |
# +--------------------------+----------+------------------+--------+------------------+----------+-----------+------------+
#
#
# Result for train_trader_59abf_00000:
#   date: 2023-01-24_15-12-48
#   done: false
#   experiment_id: 90ce3b741f3e4b32bbee2f7d57a651f4
#   hostname: ffed65665576
#   iterations_since_restore: 9746
#   loss: 0.9965717040898832
#   loss_act: 1.9151274994151508
#   loss_ud: 0.9965717040898832
#   node_ip: 172.28.0.12
#   pid: 2695
#   should_checkpoint: true
#   time_since_restore: 22851.89397740364
#   time_this_iter_s: 2.6706693172454834
#   time_total_s: 22851.89397740364
#   timestamp: 1674573168
#   timesteps_since_restore: 0
#   training_iteration: 9746
#   trial_id: 59abf_00000
#   warmup_time: 0.0044901371002197266
#
# == Status ==
# Current time: 2023-01-24 15:12:51 (running for 06:20:57.56)
# Memory usage on this node: 5.5/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4096.000: -0.7689869808564197 | Iter 1024.000: -1.4568044934603481 | Iter 256.000: -1.622901872097414 | Iter 64.000: -1.6882946276147084 | Iter 16.000: -1.7309075328366605 | Iter 4.000: -2.6063361552626216 | Iter 1.000: -2.8950388669598555
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.89 GiB heap, 0.0/24.95 GiB objects
# Current best trial: 59abf_00000 with loss=1.0307637516889834 and parameters={'factor_num': 8, 'd_model': 64, 'dim_ff': 64, 'asset_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.3, 'tt_nhead': 4, 'tt_nlayers': 4, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KRW-XRP'}, 'action_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_name': 'trading_bc_transformer2', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_bc_transformer/train_dataset_5.pkl', 'epoch_size': 10000, 'batch_size': 2048, 'lr': 0.0001, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 512, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'sched_term': 5, 'lr_decay': 0.99, 'num_workers': 8, 'asset_idx': 0, 'pretrain_epoch_prob': 0.5, 'updown_coeff': 0.5}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_bc_transformer2/trading_bc_transformer2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |    loss |   loss_ud |   loss_act |
# |--------------------------+----------+------------------+--------+------------------+---------+-----------+------------|
# | train_trader_59abf_00000 | RUNNING  | 172.28.0.12:2695 |   9747 |          22854.6 | 1.03076 |   1.03076 |    1.95306 |
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
#
#
# Result for train_trader_59abf_00000:
#   date: 2023-01-24_15-12-54
#   done: false
#   experiment_id: 90ce3b741f3e4b32bbee2f7d57a651f4
#   hostname: ffed65665576
#   iterations_since_restore: 9748
#   loss: 1.0046312145364868
#   loss_act: 1.9358529577566828
#   loss_ud: 1.0046312145364868
#   node_ip: 172.28.0.12
#   pid: 2695
#   should_checkpoint: true
#   time_since_restore: 22857.210337400436
#   time_this_iter_s: 2.646333932876587
#   time_total_s: 22857.210337400436
#   timestamp: 1674573174
#   timesteps_since_restore: 0
#   training_iteration: 9748
#   trial_id: 59abf_00000
#   warmup_time: 0.0044901371002197266
#
# == Status ==
# Current time: 2023-01-24 15:12:57 (running for 06:21:03.09)
# Memory usage on this node: 5.5/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4096.000: -0.7689869808564197 | Iter 1024.000: -1.4568044934603481 | Iter 256.000: -1.622901872097414 | Iter 64.000: -1.6882946276147084 | Iter 16.000: -1.7309075328366605 | Iter 4.000: -2.6063361552626216 | Iter 1.000: -2.8950388669598555
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.89 GiB heap, 0.0/24.95 GiB objects
# Current best trial: 59abf_00000 with loss=1.0046312145364868 and parameters={'factor_num': 8, 'd_model': 64, 'dim_ff': 64, 'asset_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.3, 'tt_nhead': 4, 'tt_nlayers': 4, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KRW-XRP'}, 'action_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_name': 'trading_bc_transformer2', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_bc_transformer/train_dataset_5.pkl', 'epoch_size': 10000, 'batch_size': 2048, 'lr': 0.0001, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 512, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'sched_term': 5, 'lr_decay': 0.99, 'num_workers': 8, 'asset_idx': 0, 'pretrain_epoch_prob': 0.5, 'updown_coeff': 0.5}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_bc_transformer2/trading_bc_transformer2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |    loss |   loss_ud |   loss_act |
# |--------------------------+----------+------------------+--------+------------------+---------+-----------+------------|
# | train_trader_59abf_00000 | RUNNING  | 172.28.0.12:2695 |   9748 |          22857.2 | 1.00463 |   1.00463 |    1.93585 |
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
#
#
# Result for train_trader_59abf_00000:
#   date: 2023-01-24_15-12-59
#   done: false
#   experiment_id: 90ce3b741f3e4b32bbee2f7d57a651f4
#   hostname: ffed65665576
#   iterations_since_restore: 9749
#   loss: 1.0126155721393661
#   loss_act: 1.9286850702726905
#   loss_ud: 1.0126155721393661
#   node_ip: 172.28.0.12
#   pid: 2695
#   should_checkpoint: true
#   time_since_restore: 22862.744120121002
#   time_this_iter_s: 5.533782720565796
#   time_total_s: 22862.744120121002
#   timestamp: 1674573179
#   timesteps_since_restore: 0
#   training_iteration: 9749
#   trial_id: 59abf_00000
#   warmup_time: 0.0044901371002197266
#
# == Status ==
# Current time: 2023-01-24 15:13:02 (running for 06:21:08.39)
# Memory usage on this node: 5.5/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4096.000: -0.7689869808564197 | Iter 1024.000: -1.4568044934603481 | Iter 256.000: -1.622901872097414 | Iter 64.000: -1.6882946276147084 | Iter 16.000: -1.7309075328366605 | Iter 4.000: -2.6063361552626216 | Iter 1.000: -2.8950388669598555
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.89 GiB heap, 0.0/24.95 GiB objects
# Current best trial: 59abf_00000 with loss=1.010225443372264 and parameters={'factor_num': 8, 'd_model': 64, 'dim_ff': 64, 'asset_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.3, 'tt_nhead': 4, 'tt_nlayers': 4, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KRW-XRP'}, 'action_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_name': 'trading_bc_transformer2', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_bc_transformer/train_dataset_5.pkl', 'epoch_size': 10000, 'batch_size': 2048, 'lr': 0.0001, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 512, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'sched_term': 5, 'lr_decay': 0.99, 'num_workers': 8, 'asset_idx': 0, 'pretrain_epoch_prob': 0.5, 'updown_coeff': 0.5}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_bc_transformer2/trading_bc_transformer2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |    loss |   loss_ud |   loss_act |
# |--------------------------+----------+------------------+--------+------------------+---------+-----------+------------|
# | train_trader_59abf_00000 | RUNNING  | 172.28.0.12:2695 |   9750 |          22865.4 | 1.01023 |   1.01023 |    1.92999 |
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
#
#
# Result for train_trader_59abf_00000:
#   date: 2023-01-24_15-13-05
#   done: false
#   experiment_id: 90ce3b741f3e4b32bbee2f7d57a651f4
#   hostname: ffed65665576
#   iterations_since_restore: 9751
#   loss: 1.0012963982620269
#   loss_act: 1.93125461761084
#   loss_ud: 1.0012963982620269
#   node_ip: 172.28.0.12
#   pid: 2695
#   should_checkpoint: true
#   time_since_restore: 22868.018963575363
#   time_this_iter_s: 2.6279850006103516
#   time_total_s: 22868.018963575363
#   timestamp: 1674573185
#   timesteps_since_restore: 0
#   training_iteration: 9751
#   trial_id: 59abf_00000
#   warmup_time: 0.0044901371002197266
#
# == Status ==
# Current time: 2023-01-24 15:13:07 (running for 06:21:13.69)
# Memory usage on this node: 5.5/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4096.000: -0.7689869808564197 | Iter 1024.000: -1.4568044934603481 | Iter 256.000: -1.622901872097414 | Iter 64.000: -1.6882946276147084 | Iter 16.000: -1.7309075328366605 | Iter 4.000: -2.6063361552626216 | Iter 1.000: -2.8950388669598555
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.89 GiB heap, 0.0/24.95 GiB objects
# Current best trial: 59abf_00000 with loss=0.982854679076192 and parameters={'factor_num': 8, 'd_model': 64, 'dim_ff': 64, 'asset_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.3, 'tt_nhead': 4, 'tt_nlayers': 4, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KRW-XRP'}, 'action_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_name': 'trading_bc_transformer2', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_bc_transformer/train_dataset_5.pkl', 'epoch_size': 10000, 'batch_size': 2048, 'lr': 0.0001, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 512, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'sched_term': 5, 'lr_decay': 0.99, 'num_workers': 8, 'asset_idx': 0, 'pretrain_epoch_prob': 0.5, 'updown_coeff': 0.5}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_bc_transformer2/trading_bc_transformer2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+----------+-----------+------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |     loss |   loss_ud |   loss_act |
# |--------------------------+----------+------------------+--------+------------------+----------+-----------+------------|
# | train_trader_59abf_00000 | RUNNING  | 172.28.0.12:2695 |   9752 |          22870.7 | 0.982855 |  0.982855 |    1.90368 |
# +--------------------------+----------+------------------+--------+------------------+----------+-----------+------------+
#
#
# Result for train_trader_59abf_00000:
#   date: 2023-01-24_15-13-10
#   done: false
#   experiment_id: 90ce3b741f3e4b32bbee2f7d57a651f4
#   hostname: ffed65665576
#   iterations_since_restore: 9753
#   loss: 0.9932809886844082
#   loss_act: 1.9263056992557837
#   loss_ud: 0.9932809886844082
#   node_ip: 172.28.0.12
#   pid: 2695
#   should_checkpoint: true
#   time_since_restore: 22873.348769664764
#   time_this_iter_s: 2.6481852531433105
#   time_total_s: 22873.348769664764
#   timestamp: 1674573190
#   timesteps_since_restore: 0
#   training_iteration: 9753
#   trial_id: 59abf_00000
#   warmup_time: 0.0044901371002197266
#
# == Status ==
# Current time: 2023-01-24 15:13:12 (running for 06:21:18.98)
# Memory usage on this node: 5.5/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4096.000: -0.7689869808564197 | Iter 1024.000: -1.4568044934603481 | Iter 256.000: -1.622901872097414 | Iter 64.000: -1.6882946276147084 | Iter 16.000: -1.7309075328366605 | Iter 4.000: -2.6063361552626216 | Iter 1.000: -2.8950388669598555
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.89 GiB heap, 0.0/24.95 GiB objects
# Current best trial: 59abf_00000 with loss=1.0100466030530324 and parameters={'factor_num': 8, 'd_model': 64, 'dim_ff': 64, 'asset_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.3, 'tt_nhead': 4, 'tt_nlayers': 4, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KRW-XRP'}, 'action_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_name': 'trading_bc_transformer2', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_bc_transformer/train_dataset_5.pkl', 'epoch_size': 10000, 'batch_size': 2048, 'lr': 0.0001, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 512, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'sched_term': 5, 'lr_decay': 0.99, 'num_workers': 8, 'asset_idx': 0, 'pretrain_epoch_prob': 0.5, 'updown_coeff': 0.5}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_bc_transformer2/trading_bc_transformer2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |    loss |   loss_ud |   loss_act |
# |--------------------------+----------+------------------+--------+------------------+---------+-----------+------------|
# | train_trader_59abf_00000 | RUNNING  | 172.28.0.12:2695 |   9754 |            22876 | 1.01005 |   1.01005 |    1.92063 |
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
#
#
# Result for train_trader_59abf_00000:
#   date: 2023-01-24_15-13-15
#   done: false
#   experiment_id: 90ce3b741f3e4b32bbee2f7d57a651f4
#   hostname: ffed65665576
#   iterations_since_restore: 9755
#   loss: 0.9896727380858388
#   loss_act: 1.9306372847104791
#   loss_ud: 0.9896727380858388
#   node_ip: 172.28.0.12
#   pid: 2695
#   should_checkpoint: true
#   time_since_restore: 22878.656011343002
#   time_this_iter_s: 2.667987108230591
#   time_total_s: 22878.656011343002
#   timestamp: 1674573195
#   timesteps_since_restore: 0
#   training_iteration: 9755
#   trial_id: 59abf_00000
#   warmup_time: 0.0044901371002197266
#
# == Status ==
# Current time: 2023-01-24 15:13:18 (running for 06:21:24.30)
# Memory usage on this node: 5.5/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4096.000: -0.7689869808564197 | Iter 1024.000: -1.4568044934603481 | Iter 256.000: -1.622901872097414 | Iter 64.000: -1.6882946276147084 | Iter 16.000: -1.7309075328366605 | Iter 4.000: -2.6063361552626216 | Iter 1.000: -2.8950388669598555
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.89 GiB heap, 0.0/24.95 GiB objects
# Current best trial: 59abf_00000 with loss=1.004315017851733 and parameters={'factor_num': 8, 'd_model': 64, 'dim_ff': 64, 'asset_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.3, 'tt_nhead': 4, 'tt_nlayers': 4, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KRW-XRP'}, 'action_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_name': 'trading_bc_transformer2', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_bc_transformer/train_dataset_5.pkl', 'epoch_size': 10000, 'batch_size': 2048, 'lr': 0.0001, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 512, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'sched_term': 5, 'lr_decay': 0.99, 'num_workers': 8, 'asset_idx': 0, 'pretrain_epoch_prob': 0.5, 'updown_coeff': 0.5}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_bc_transformer2/trading_bc_transformer2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |    loss |   loss_ud |   loss_act |
# |--------------------------+----------+------------------+--------+------------------+---------+-----------+------------|
# | train_trader_59abf_00000 | RUNNING  | 172.28.0.12:2695 |   9756 |          22881.3 | 1.00432 |   1.00432 |    1.91518 |
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
#
#
# Result for train_trader_59abf_00000:
#   date: 2023-01-24_15-13-20
#   done: false
#   experiment_id: 90ce3b741f3e4b32bbee2f7d57a651f4
#   hostname: ffed65665576
#   iterations_since_restore: 9757
#   loss: 1.0082505557378354
#   loss_act: 1.928695525696261
#   loss_ud: 1.0082505557378354
#   node_ip: 172.28.0.12
#   pid: 2695
#   should_checkpoint: true
#   time_since_restore: 22883.98369193077
#   time_this_iter_s: 2.678267240524292
#   time_total_s: 22883.98369193077
#   timestamp: 1674573200
#   timesteps_since_restore: 0
#   training_iteration: 9757
#   trial_id: 59abf_00000
#   warmup_time: 0.0044901371002197266
#
# == Status ==
# Current time: 2023-01-24 15:13:23 (running for 06:21:29.63)
# Memory usage on this node: 5.5/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4096.000: -0.7689869808564197 | Iter 1024.000: -1.4568044934603481 | Iter 256.000: -1.622901872097414 | Iter 64.000: -1.6882946276147084 | Iter 16.000: -1.7309075328366605 | Iter 4.000: -2.6063361552626216 | Iter 1.000: -2.8950388669598555
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.89 GiB heap, 0.0/24.95 GiB objects
# Current best trial: 59abf_00000 with loss=1.0161145433766754 and parameters={'factor_num': 8, 'd_model': 64, 'dim_ff': 64, 'asset_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.3, 'tt_nhead': 4, 'tt_nlayers': 4, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KRW-XRP'}, 'action_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_name': 'trading_bc_transformer2', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_bc_transformer/train_dataset_5.pkl', 'epoch_size': 10000, 'batch_size': 2048, 'lr': 0.0001, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 512, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'sched_term': 5, 'lr_decay': 0.99, 'num_workers': 8, 'asset_idx': 0, 'pretrain_epoch_prob': 0.5, 'updown_coeff': 0.5}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_bc_transformer2/trading_bc_transformer2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |    loss |   loss_ud |   loss_act |
# |--------------------------+----------+------------------+--------+------------------+---------+-----------+------------|
# | train_trader_59abf_00000 | RUNNING  | 172.28.0.12:2695 |   9758 |          22886.6 | 1.01611 |   1.01611 |    1.91613 |
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
#
#
# Result for train_trader_59abf_00000:
#   date: 2023-01-24_15-13-26
#   done: false
#   experiment_id: 90ce3b741f3e4b32bbee2f7d57a651f4
#   hostname: ffed65665576
#   iterations_since_restore: 9759
#   loss: 0.992923996141472
#   loss_act: 1.9159865289120872
#   loss_ud: 0.992923996141472
#   node_ip: 172.28.0.12
#   pid: 2695
#   should_checkpoint: true
#   time_since_restore: 22889.30721282959
#   time_this_iter_s: 2.6726861000061035
#   time_total_s: 22889.30721282959
#   timestamp: 1674573206
#   timesteps_since_restore: 0
#   training_iteration: 9759
#   trial_id: 59abf_00000
#   warmup_time: 0.0044901371002197266
#
# == Status ==
# Current time: 2023-01-24 15:13:28 (running for 06:21:34.96)
# Memory usage on this node: 5.5/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4096.000: -0.7689869808564197 | Iter 1024.000: -1.4568044934603481 | Iter 256.000: -1.622901872097414 | Iter 64.000: -1.6882946276147084 | Iter 16.000: -1.7309075328366605 | Iter 4.000: -2.6063361552626216 | Iter 1.000: -2.8950388669598555
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.89 GiB heap, 0.0/24.95 GiB objects
# Current best trial: 59abf_00000 with loss=1.0131565201748869 and parameters={'factor_num': 8, 'd_model': 64, 'dim_ff': 64, 'asset_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.3, 'tt_nhead': 4, 'tt_nlayers': 4, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KRW-XRP'}, 'action_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_name': 'trading_bc_transformer2', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_bc_transformer/train_dataset_5.pkl', 'epoch_size': 10000, 'batch_size': 2048, 'lr': 0.0001, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 512, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'sched_term': 5, 'lr_decay': 0.99, 'num_workers': 8, 'asset_idx': 0, 'pretrain_epoch_prob': 0.5, 'updown_coeff': 0.5}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_bc_transformer2/trading_bc_transformer2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |    loss |   loss_ud |   loss_act |
# |--------------------------+----------+------------------+--------+------------------+---------+-----------+------------|
# | train_trader_59abf_00000 | RUNNING  | 172.28.0.12:2695 |   9760 |            22892 | 1.01316 |   1.01316 |    1.93395 |
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
#
#
# Result for train_trader_59abf_00000:
#   date: 2023-01-24_15-13-31
#   done: false
#   experiment_id: 90ce3b741f3e4b32bbee2f7d57a651f4
#   hostname: ffed65665576
#   iterations_since_restore: 9761
#   loss: 1.0098619204715633
#   loss_act: 1.9449256555417997
#   loss_ud: 1.0098619204715633
#   node_ip: 172.28.0.12
#   pid: 2695
#   should_checkpoint: true
#   time_since_restore: 22894.589241027832
#   time_this_iter_s: 2.6277589797973633
#   time_total_s: 22894.589241027832
#   timestamp: 1674573211
#   timesteps_since_restore: 0
#   training_iteration: 9761
#   trial_id: 59abf_00000
#   warmup_time: 0.0044901371002197266
#
# == Status ==
# Current time: 2023-01-24 15:13:34 (running for 06:21:40.24)
# Memory usage on this node: 5.5/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4096.000: -0.7689869808564197 | Iter 1024.000: -1.4568044934603481 | Iter 256.000: -1.622901872097414 | Iter 64.000: -1.6882946276147084 | Iter 16.000: -1.7309075328366605 | Iter 4.000: -2.6063361552626216 | Iter 1.000: -2.8950388669598555
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.89 GiB heap, 0.0/24.95 GiB objects
# Current best trial: 59abf_00000 with loss=1.0334409846612949 and parameters={'factor_num': 8, 'd_model': 64, 'dim_ff': 64, 'asset_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.3, 'tt_nhead': 4, 'tt_nlayers': 4, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KRW-XRP'}, 'action_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_name': 'trading_bc_transformer2', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_bc_transformer/train_dataset_5.pkl', 'epoch_size': 10000, 'batch_size': 2048, 'lr': 0.0001, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 512, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'sched_term': 5, 'lr_decay': 0.99, 'num_workers': 8, 'asset_idx': 0, 'pretrain_epoch_prob': 0.5, 'updown_coeff': 0.5}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_bc_transformer2/trading_bc_transformer2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |    loss |   loss_ud |   loss_act |
# |--------------------------+----------+------------------+--------+------------------+---------+-----------+------------|
# | train_trader_59abf_00000 | RUNNING  | 172.28.0.12:2695 |   9762 |          22897.2 | 1.03344 |   1.03344 |    1.93205 |
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
#
#
# Result for train_trader_59abf_00000:
#   date: 2023-01-24_15-13-36
#   done: false
#   experiment_id: 90ce3b741f3e4b32bbee2f7d57a651f4
#   hostname: ffed65665576
#   iterations_since_restore: 9763
#   loss: 0.9961123768134967
#   loss_act: 1.9425528560122909
#   loss_ud: 0.9961123768134967
#   node_ip: 172.28.0.12
#   pid: 2695
#   should_checkpoint: true
#   time_since_restore: 22899.898469686508
#   time_this_iter_s: 2.6538054943084717
#   time_total_s: 22899.898469686508
#   timestamp: 1674573216
#   timesteps_since_restore: 0
#   training_iteration: 9763
#   trial_id: 59abf_00000
#   warmup_time: 0.0044901371002197266
#
# == Status ==
# Current time: 2023-01-24 15:13:39 (running for 06:21:45.64)
# Memory usage on this node: 5.5/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4096.000: -0.7689869808564197 | Iter 1024.000: -1.4568044934603481 | Iter 256.000: -1.622901872097414 | Iter 64.000: -1.6882946276147084 | Iter 16.000: -1.7309075328366605 | Iter 4.000: -2.6063361552626216 | Iter 1.000: -2.8950388669598555
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.89 GiB heap, 0.0/24.95 GiB objects
# Current best trial: 59abf_00000 with loss=0.9985889413410248 and parameters={'factor_num': 8, 'd_model': 64, 'dim_ff': 64, 'asset_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.3, 'tt_nhead': 4, 'tt_nlayers': 4, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KRW-XRP'}, 'action_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_name': 'trading_bc_transformer2', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_bc_transformer/train_dataset_5.pkl', 'epoch_size': 10000, 'batch_size': 2048, 'lr': 0.0001, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 512, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'sched_term': 5, 'lr_decay': 0.99, 'num_workers': 8, 'asset_idx': 0, 'pretrain_epoch_prob': 0.5, 'updown_coeff': 0.5}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_bc_transformer2/trading_bc_transformer2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+----------+-----------+------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |     loss |   loss_ud |   loss_act |
# |--------------------------+----------+------------------+--------+------------------+----------+-----------+------------|
# | train_trader_59abf_00000 | RUNNING  | 172.28.0.12:2695 |   9764 |          22902.6 | 0.998589 |  0.998589 |    1.92792 |
# +--------------------------+----------+------------------+--------+------------------+----------+-----------+------------+
#
#
# Result for train_trader_59abf_00000:
#   date: 2023-01-24_15-13-42
#   done: false
#   experiment_id: 90ce3b741f3e4b32bbee2f7d57a651f4
#   hostname: ffed65665576
#   iterations_since_restore: 9765
#   loss: 1.0055120072710957
#   loss_act: 1.9139991870971735
#   loss_ud: 1.0055120072710957
#   node_ip: 172.28.0.12
#   pid: 2695
#   should_checkpoint: true
#   time_since_restore: 22905.28691959381
#   time_this_iter_s: 2.6389055252075195
#   time_total_s: 22905.28691959381
#   timestamp: 1674573222
#   timesteps_since_restore: 0
#   training_iteration: 9765
#   trial_id: 59abf_00000
#   warmup_time: 0.0044901371002197266
#
# == Status ==
# Current time: 2023-01-24 15:13:44 (running for 06:21:50.94)
# Memory usage on this node: 5.5/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4096.000: -0.7689869808564197 | Iter 1024.000: -1.4568044934603481 | Iter 256.000: -1.622901872097414 | Iter 64.000: -1.6882946276147084 | Iter 16.000: -1.7309075328366605 | Iter 4.000: -2.6063361552626216 | Iter 1.000: -2.8950388669598555
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.89 GiB heap, 0.0/24.95 GiB objects
# Current best trial: 59abf_00000 with loss=1.00889623700726 and parameters={'factor_num': 8, 'd_model': 64, 'dim_ff': 64, 'asset_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.3, 'tt_nhead': 4, 'tt_nlayers': 4, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KRW-XRP'}, 'action_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_name': 'trading_bc_transformer2', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_bc_transformer/train_dataset_5.pkl', 'epoch_size': 10000, 'batch_size': 2048, 'lr': 0.0001, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 512, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'sched_term': 5, 'lr_decay': 0.99, 'num_workers': 8, 'asset_idx': 0, 'pretrain_epoch_prob': 0.5, 'updown_coeff': 0.5}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_bc_transformer2/trading_bc_transformer2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+--------+-----------+------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |   loss |   loss_ud |   loss_act |
# |--------------------------+----------+------------------+--------+------------------+--------+-----------+------------|
# | train_trader_59abf_00000 | RUNNING  | 172.28.0.12:2695 |   9766 |            22908 | 1.0089 |    1.0089 |    1.93896 |
# +--------------------------+----------+------------------+--------+------------------+--------+-----------+------------+
#
#
# Result for train_trader_59abf_00000:
#   date: 2023-01-24_15-13-47
#   done: false
#   experiment_id: 90ce3b741f3e4b32bbee2f7d57a651f4
#   hostname: ffed65665576
#   iterations_since_restore: 9767
#   loss: 0.9942865927706128
#   loss_act: 1.9326805635522817
#   loss_ud: 0.9942865927706128
#   node_ip: 172.28.0.12
#   pid: 2695
#   should_checkpoint: true
#   time_since_restore: 22910.585123062134
#   time_this_iter_s: 2.634343147277832
#   time_total_s: 22910.585123062134
#   timestamp: 1674573227
#   timesteps_since_restore: 0
#   training_iteration: 9767
#   trial_id: 59abf_00000
#   warmup_time: 0.0044901371002197266
#
# == Status ==
# Current time: 2023-01-24 15:13:50 (running for 06:21:56.25)
# Memory usage on this node: 5.5/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4096.000: -0.7689869808564197 | Iter 1024.000: -1.4568044934603481 | Iter 256.000: -1.622901872097414 | Iter 64.000: -1.6882946276147084 | Iter 16.000: -1.7309075328366605 | Iter 4.000: -2.6063361552626216 | Iter 1.000: -2.8950388669598555
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.89 GiB heap, 0.0/24.95 GiB objects
# Current best trial: 59abf_00000 with loss=0.9914570003953546 and parameters={'factor_num': 8, 'd_model': 64, 'dim_ff': 64, 'asset_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.3, 'tt_nhead': 4, 'tt_nlayers': 4, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KRW-XRP'}, 'action_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_name': 'trading_bc_transformer2', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_bc_transformer/train_dataset_5.pkl', 'epoch_size': 10000, 'batch_size': 2048, 'lr': 0.0001, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 512, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'sched_term': 5, 'lr_decay': 0.99, 'num_workers': 8, 'asset_idx': 0, 'pretrain_epoch_prob': 0.5, 'updown_coeff': 0.5}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_bc_transformer2/trading_bc_transformer2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+----------+-----------+------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |     loss |   loss_ud |   loss_act |
# |--------------------------+----------+------------------+--------+------------------+----------+-----------+------------|
# | train_trader_59abf_00000 | RUNNING  | 172.28.0.12:2695 |   9768 |          22913.3 | 0.991457 |  0.991457 |    1.93493 |
# +--------------------------+----------+------------------+--------+------------------+----------+-----------+------------+
#
#
# Result for train_trader_59abf_00000:
#   date: 2023-01-24_15-13-52
#   done: false
#   experiment_id: 90ce3b741f3e4b32bbee2f7d57a651f4
#   hostname: ffed65665576
#   iterations_since_restore: 9769
#   loss: 1.0113741278999373
#   loss_act: 1.9296323575810803
#   loss_ud: 1.0113741278999373
#   node_ip: 172.28.0.12
#   pid: 2695
#   should_checkpoint: true
#   time_since_restore: 22915.890102386475
#   time_this_iter_s: 2.6335158348083496
#   time_total_s: 22915.890102386475
#   timestamp: 1674573232
#   timesteps_since_restore: 0
#   training_iteration: 9769
#   trial_id: 59abf_00000
#   warmup_time: 0.0044901371002197266
#
# == Status ==
# Current time: 2023-01-24 15:13:55 (running for 06:22:01.90)
# Memory usage on this node: 5.5/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4096.000: -0.7689869808564197 | Iter 1024.000: -1.4568044934603481 | Iter 256.000: -1.622901872097414 | Iter 64.000: -1.6882946276147084 | Iter 16.000: -1.7309075328366605 | Iter 4.000: -2.6063361552626216 | Iter 1.000: -2.8950388669598555
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.89 GiB heap, 0.0/24.95 GiB objects
# Current best trial: 59abf_00000 with loss=1.0113741278999373 and parameters={'factor_num': 8, 'd_model': 64, 'dim_ff': 64, 'asset_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.3, 'tt_nhead': 4, 'tt_nlayers': 4, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KRW-XRP'}, 'action_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_name': 'trading_bc_transformer2', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_bc_transformer/train_dataset_5.pkl', 'epoch_size': 10000, 'batch_size': 2048, 'lr': 0.0001, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 512, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'sched_term': 5, 'lr_decay': 0.99, 'num_workers': 8, 'asset_idx': 0, 'pretrain_epoch_prob': 0.5, 'updown_coeff': 0.5}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_bc_transformer2/trading_bc_transformer2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |    loss |   loss_ud |   loss_act |
# |--------------------------+----------+------------------+--------+------------------+---------+-----------+------------|
# | train_trader_59abf_00000 | RUNNING  | 172.28.0.12:2695 |   9769 |          22915.9 | 1.01137 |   1.01137 |    1.92963 |
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
#
#
# Result for train_trader_59abf_00000:
#   date: 2023-01-24_15-13-58
#   done: false
#   experiment_id: 90ce3b741f3e4b32bbee2f7d57a651f4
#   hostname: ffed65665576
#   iterations_since_restore: 9770
#   loss: 0.985270218296925
#   loss_act: 1.9066874444758073
#   loss_ud: 0.985270218296925
#   node_ip: 172.28.0.12
#   pid: 2695
#   should_checkpoint: true
#   time_since_restore: 22921.58216547966
#   time_this_iter_s: 5.692063093185425
#   time_total_s: 22921.58216547966
#   timestamp: 1674573238
#   timesteps_since_restore: 0
#   training_iteration: 9770
#   trial_id: 59abf_00000
#   warmup_time: 0.0044901371002197266
#
# == Status ==
# Current time: 2023-01-24 15:14:01 (running for 06:22:07.23)
# Memory usage on this node: 5.5/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4096.000: -0.7689869808564197 | Iter 1024.000: -1.4568044934603481 | Iter 256.000: -1.622901872097414 | Iter 64.000: -1.6882946276147084 | Iter 16.000: -1.7309075328366605 | Iter 4.000: -2.6063361552626216 | Iter 1.000: -2.8950388669598555
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.89 GiB heap, 0.0/24.95 GiB objects
# Current best trial: 59abf_00000 with loss=1.0031182269037495 and parameters={'factor_num': 8, 'd_model': 64, 'dim_ff': 64, 'asset_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.3, 'tt_nhead': 4, 'tt_nlayers': 4, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KRW-XRP'}, 'action_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_name': 'trading_bc_transformer2', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_bc_transformer/train_dataset_5.pkl', 'epoch_size': 10000, 'batch_size': 2048, 'lr': 0.0001, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 512, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'sched_term': 5, 'lr_decay': 0.99, 'num_workers': 8, 'asset_idx': 0, 'pretrain_epoch_prob': 0.5, 'updown_coeff': 0.5}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_bc_transformer2/trading_bc_transformer2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |    loss |   loss_ud |   loss_act |
# |--------------------------+----------+------------------+--------+------------------+---------+-----------+------------|
# | train_trader_59abf_00000 | RUNNING  | 172.28.0.12:2695 |   9771 |          22924.2 | 1.00312 |   1.00312 |    1.90434 |
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
#
#
# Result for train_trader_59abf_00000:
#   date: 2023-01-24_15-14-03
# ...
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |    loss |   loss_ud |   loss_act |
# |--------------------------+----------+------------------+--------+------------------+---------+-----------+------------|
# | train_trader_59abf_00000 | RUNNING  | 172.28.0.12:2695 |   9992 |          23536.4 | 1.01286 |   1.01286 |    1.93607 |
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
#
#
# Result for train_trader_59abf_00000:
#   date: 2023-01-24_15-24-16
#   done: false
#   experiment_id: 90ce3b741f3e4b32bbee2f7d57a651f4
#   hostname: ffed65665576
#   iterations_since_restore: 9993
#   loss: 0.9792409223675076
#   loss_act: 1.903106421732374
#   loss_ud: 0.9792409223675076
#   node_ip: 172.28.0.12
#   pid: 2695
#   should_checkpoint: true
#   time_since_restore: 23539.05512070656
#   time_this_iter_s: 2.6394193172454834
#   time_total_s: 23539.05512070656
#   timestamp: 1674573856
#   timesteps_since_restore: 0
#   training_iteration: 9993
#   trial_id: 59abf_00000
#   warmup_time: 0.0044901371002197266
#
# == Status ==
# Current time: 2023-01-24 15:24:19 (running for 06:32:25.13)
# Memory usage on this node: 5.5/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4096.000: -0.7689869808564197 | Iter 1024.000: -1.4568044934603481 | Iter 256.000: -1.622901872097414 | Iter 64.000: -1.6882946276147084 | Iter 16.000: -1.7309075328366605 | Iter 4.000: -2.6063361552626216 | Iter 1.000: -2.8950388669598555
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.89 GiB heap, 0.0/24.95 GiB objects
# Current best trial: 59abf_00000 with loss=0.9792409223675076 and parameters={'factor_num': 8, 'd_model': 64, 'dim_ff': 64, 'asset_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.3, 'tt_nhead': 4, 'tt_nlayers': 4, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KRW-XRP'}, 'action_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_name': 'trading_bc_transformer2', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_bc_transformer/train_dataset_5.pkl', 'epoch_size': 10000, 'batch_size': 2048, 'lr': 0.0001, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 512, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'sched_term': 5, 'lr_decay': 0.99, 'num_workers': 8, 'asset_idx': 0, 'pretrain_epoch_prob': 0.5, 'updown_coeff': 0.5}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_bc_transformer2/trading_bc_transformer2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+----------+-----------+------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |     loss |   loss_ud |   loss_act |
# |--------------------------+----------+------------------+--------+------------------+----------+-----------+------------|
# | train_trader_59abf_00000 | RUNNING  | 172.28.0.12:2695 |   9993 |          23539.1 | 0.979241 |  0.979241 |    1.90311 |
# +--------------------------+----------+------------------+--------+------------------+----------+-----------+------------+
#
#
# Result for train_trader_59abf_00000:
#   date: 2023-01-24_15-24-21
#   done: false
#   experiment_id: 90ce3b741f3e4b32bbee2f7d57a651f4
#   hostname: ffed65665576
#   iterations_since_restore: 9994
#   loss: 0.98297349206111
#   loss_act: 1.9034654382289824
#   loss_ud: 0.98297349206111
#   node_ip: 172.28.0.12
#   pid: 2695
#   should_checkpoint: true
#   time_since_restore: 23544.78639793396
#   time_this_iter_s: 5.731277227401733
#   time_total_s: 23544.78639793396
#   timestamp: 1674573861
#   timesteps_since_restore: 0
#   training_iteration: 9994
#   trial_id: 59abf_00000
#   warmup_time: 0.0044901371002197266
#
# == Status ==
# Current time: 2023-01-24 15:24:24 (running for 06:32:30.40)
# Memory usage on this node: 5.5/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4096.000: -0.7689869808564197 | Iter 1024.000: -1.4568044934603481 | Iter 256.000: -1.622901872097414 | Iter 64.000: -1.6882946276147084 | Iter 16.000: -1.7309075328366605 | Iter 4.000: -2.6063361552626216 | Iter 1.000: -2.8950388669598555
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.89 GiB heap, 0.0/24.95 GiB objects
# Current best trial: 59abf_00000 with loss=1.0110379210150486 and parameters={'factor_num': 8, 'd_model': 64, 'dim_ff': 64, 'asset_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.3, 'tt_nhead': 4, 'tt_nlayers': 4, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KRW-XRP'}, 'action_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_name': 'trading_bc_transformer2', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_bc_transformer/train_dataset_5.pkl', 'epoch_size': 10000, 'batch_size': 2048, 'lr': 0.0001, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 512, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'sched_term': 5, 'lr_decay': 0.99, 'num_workers': 8, 'asset_idx': 0, 'pretrain_epoch_prob': 0.5, 'updown_coeff': 0.5}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_bc_transformer2/trading_bc_transformer2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |    loss |   loss_ud |   loss_act |
# |--------------------------+----------+------------------+--------+------------------+---------+-----------+------------|
# | train_trader_59abf_00000 | RUNNING  | 172.28.0.12:2695 |   9995 |          23547.4 | 1.01104 |   1.01104 |    1.90224 |
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
#
#
# Result for train_trader_59abf_00000:
#   date: 2023-01-24_15-24-27
#   done: false
#   experiment_id: 90ce3b741f3e4b32bbee2f7d57a651f4
#   hostname: ffed65665576
#   iterations_since_restore: 9996
#   loss: 1.004210776107364
#   loss_act: 1.9237058565872898
#   loss_ud: 1.004210776107364
#   node_ip: 172.28.0.12
#   pid: 2695
#   should_checkpoint: true
#   time_since_restore: 23550.074771404266
#   time_this_iter_s: 2.669708728790283
#   time_total_s: 23550.074771404266
#   timestamp: 1674573867
#   timesteps_since_restore: 0
#   training_iteration: 9996
#   trial_id: 59abf_00000
#   warmup_time: 0.0044901371002197266
#
# == Status ==
# Current time: 2023-01-24 15:24:29 (running for 06:32:35.70)
# Memory usage on this node: 5.5/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4096.000: -0.7689869808564197 | Iter 1024.000: -1.4568044934603481 | Iter 256.000: -1.622901872097414 | Iter 64.000: -1.6882946276147084 | Iter 16.000: -1.7309075328366605 | Iter 4.000: -2.6063361552626216 | Iter 1.000: -2.8950388669598555
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.89 GiB heap, 0.0/24.95 GiB objects
# Current best trial: 59abf_00000 with loss=1.0045869645913628 and parameters={'factor_num': 8, 'd_model': 64, 'dim_ff': 64, 'asset_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.3, 'tt_nhead': 4, 'tt_nlayers': 4, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KRW-XRP'}, 'action_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_name': 'trading_bc_transformer2', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_bc_transformer/train_dataset_5.pkl', 'epoch_size': 10000, 'batch_size': 2048, 'lr': 0.0001, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 512, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'sched_term': 5, 'lr_decay': 0.99, 'num_workers': 8, 'asset_idx': 0, 'pretrain_epoch_prob': 0.5, 'updown_coeff': 0.5}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_bc_transformer2/trading_bc_transformer2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |    loss |   loss_ud |   loss_act |
# |--------------------------+----------+------------------+--------+------------------+---------+-----------+------------|
# | train_trader_59abf_00000 | RUNNING  | 172.28.0.12:2695 |   9997 |          23552.7 | 1.00459 |   1.00459 |    1.91012 |
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
#
#
# Result for train_trader_59abf_00000:
#   date: 2023-01-24_15-24-32
#   done: false
#   experiment_id: 90ce3b741f3e4b32bbee2f7d57a651f4
#   hostname: ffed65665576
#   iterations_since_restore: 9998
#   loss: 0.9818095528901779
#   loss_act: 1.9098189627965743
#   loss_ud: 0.9818095528901779
#   node_ip: 172.28.0.12
#   pid: 2695
#   should_checkpoint: true
#   time_since_restore: 23555.347544431686
#   time_this_iter_s: 2.6392316818237305
#   time_total_s: 23555.347544431686
#   timestamp: 1674573872
#   timesteps_since_restore: 0
#   training_iteration: 9998
#   trial_id: 59abf_00000
#   warmup_time: 0.0044901371002197266
#
# == Status ==
# Current time: 2023-01-24 15:24:35 (running for 06:32:41.01)
# Memory usage on this node: 5.5/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4096.000: -0.7689869808564197 | Iter 1024.000: -1.4568044934603481 | Iter 256.000: -1.622901872097414 | Iter 64.000: -1.6882946276147084 | Iter 16.000: -1.7309075328366605 | Iter 4.000: -2.6063361552626216 | Iter 1.000: -2.8950388669598555
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.89 GiB heap, 0.0/24.95 GiB objects
# Current best trial: 59abf_00000 with loss=1.002235133716086 and parameters={'factor_num': 8, 'd_model': 64, 'dim_ff': 64, 'asset_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.3, 'tt_nhead': 4, 'tt_nlayers': 4, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KRW-XRP'}, 'action_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_name': 'trading_bc_transformer2', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_bc_transformer/train_dataset_5.pkl', 'epoch_size': 10000, 'batch_size': 2048, 'lr': 0.0001, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 512, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'sched_term': 5, 'lr_decay': 0.99, 'num_workers': 8, 'asset_idx': 0, 'pretrain_epoch_prob': 0.5, 'updown_coeff': 0.5}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_bc_transformer2/trading_bc_transformer2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |    loss |   loss_ud |   loss_act |
# |--------------------------+----------+------------------+--------+------------------+---------+-----------+------------|
# | train_trader_59abf_00000 | RUNNING  | 172.28.0.12:2695 |   9999 |            23558 | 1.00224 |   1.00224 |     1.9038 |
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
#
#
# Result for train_trader_59abf_00000:
#   date: 2023-01-24_15-24-37
#   done: true
#   experiment_id: 90ce3b741f3e4b32bbee2f7d57a651f4
#   hostname: ffed65665576
#   iterations_since_restore: 10000
#   loss: 0.9848894222152689
#   loss_act: 1.9187480741286909
#   loss_ud: 0.9848894222152689
#   node_ip: 172.28.0.12
#   pid: 2695
#   should_checkpoint: true
#   time_since_restore: 23560.643631219864
#   time_this_iter_s: 2.6270501613616943
#   time_total_s: 23560.643631219864
#   timestamp: 1674573877
#   timesteps_since_restore: 0
#   training_iteration: 10000
#   trial_id: 59abf_00000
#   warmup_time: 0.0044901371002197266
#
# == Status ==
# Current time: 2023-01-24 15:24:40 (running for 06:32:46.61)
# Memory usage on this node: 3.2/83.5 GiB
# Using AsyncHyperBand: num_stopped=1
# Bracket: Iter 4096.000: -0.7689869808564197 | Iter 1024.000: -1.4568044934603481 | Iter 256.000: -1.622901872097414 | Iter 64.000: -1.6882946276147084 | Iter 16.000: -1.7309075328366605 | Iter 4.000: -2.6063361552626216 | Iter 1.000: -2.8950388669598555
# Resources requested: 0/8 CPUs, 0/1 GPUs, 0.0/49.89 GiB heap, 0.0/24.95 GiB objects
# Current best trial: 59abf_00000 with loss=0.9848894222152689 and parameters={'factor_num': 8, 'd_model': 64, 'dim_ff': 64, 'asset_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.3, 'tt_nhead': 4, 'tt_nlayers': 4, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KRW-XRP'}, 'action_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_name': 'trading_bc_transformer2', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_bc_transformer/train_dataset_5.pkl', 'epoch_size': 10000, 'batch_size': 2048, 'lr': 0.0001, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 512, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'sched_term': 5, 'lr_decay': 0.99, 'num_workers': 8, 'asset_idx': 0, 'pretrain_epoch_prob': 0.5, 'updown_coeff': 0.5}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_bc_transformer2/trading_bc_transformer2
# Number of trials: 1/1 (1 TERMINATED)
# +--------------------------+------------+------------------+--------+------------------+----------+-----------+------------+
# | Trial name               | status     | loc              |   iter |   total time (s) |     loss |   loss_ud |   loss_act |
# |--------------------------+------------+------------------+--------+------------------+----------+-----------+------------|
# | train_trader_59abf_00000 | TERMINATED | 172.28.0.12:2695 |  10000 |          23560.6 | 0.984889 |  0.984889 |    1.91875 |
# +--------------------------+------------+------------------+--------+------------------+----------+-----------+------------+
#
#
# 2023-01-24 15:24:40,714	INFO tune.py:762 -- Total run time: 23566.85 seconds (23563.65 seconds for the tuning loop).
# Best config is:  {'factor_num': 8, 'd_model': 64, 'dim_ff': 64, 'asset_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.3, 'tt_nhead': 4, 'tt_nlayers': 4, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KRW-XRP'}, 'action_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_name': 'trading_bc_transformer2', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_bc_transformer/train_dataset_5.pkl', 'epoch_size': 10000, 'batch_size': 2048, 'lr': 0.0001, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 512, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'sched_term': 5, 'lr_decay': 0.99, 'num_workers': 8, 'asset_idx': 0, 'pretrain_epoch_prob': 0.5, 'updown_coeff': 0.5}
# /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_bc_transformer2/trading_bc_transformer2/train_trader_59abf_00000_0_2023-01-24_08-51-54

# %%
# !nvidia-smi
# Out:
# Sat Jan 21 14:11:18 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-SXM4-40GB      Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    49W / 400W |      0MiB / 40536MiB |      4%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import torch

# %%
torch.__version__
# Out:
# '1.13.0+cu116'
