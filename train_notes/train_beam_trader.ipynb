# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd drive/MyDrive/rich/main/rich/
# Out:
# /content/drive/MyDrive/rich/main/rich

# %%
# !pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install ray[tune]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !PYTHONPATH=./ python trainers/beam_trader_train.py --epoch_size=100 --num_samples 2 --lr_scheduling --sched_term 10\
 --batch_size 32 --valid_batch_size 32
# Out:
# 2022-10-10 08:40:11,715	INFO worker.py:1518 -- Started a local Ray instance.
# 2022-10-10 08:40:12,513	WARNING function_trainable.py:620 -- Function checkpointing is disabled. This may result in unexpected behavior when using checkpointing features or certain schedulers. To enable, set the train function arguments to be `func(config, checkpoint_dir=None)`.
# == Status ==
# Current time: 2022-10-10 08:40:14 (running for 00:00:02.11)
# Memory usage on this node: 2.1/51.0 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: None | Iter 1.000: None
# Resources requested: 4.0/4 CPUs, 1.0/1 GPUs, 0.0/30.32 GiB heap, 0.0/15.16 GiB objects (0.0/1.0 accelerator_type:T4)
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/beam_trader/beam_trader
# Number of trials: 6/6 (5 PENDING, 1 RUNNING)
# +-------------------------------+----------+-------------------+--------+
# ...

# %%
# !nvidia-smi

# %%
import torch

# %%
torch.__version__
