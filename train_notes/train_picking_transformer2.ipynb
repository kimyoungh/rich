# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd drive/MyDrive/rich/main/rich/
# Out:
# /content/drive/MyDrive/rich/main/rich

# %%
# !pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install ray
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !PYTHONPATH=./ python trainers/picking_transformer2_train.py --epoch_size=2000 --num_samples 1\
 --batch_size 256 --valid_batch_size 64 --device cuda --lr 0.001 --model_name picking_transformer2
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Result for train_trader_43c5c_00000:
#   date: 2023-02-11_17-12-39
#   done: false
#   experiment_id: ca5b3fbcc86d42d9a54f70ee65baa9b5
#   hostname: 914e1e1d7c04
#   iterations_since_restore: 1866
#   loss: 1.52287837553181
#   loss_max: 3.408276157630119
#   loss_prets: 0.3625194065664944
#   node_ip: 172.28.0.12
#   pid: 26133
#   should_checkpoint: true
#   time_since_restore: 11173.809383630753
#   time_this_iter_s: 5.914596319198608
#   time_total_s: 11173.809383630753
#   timestamp: 1676135559
#   timesteps_since_restore: 0
#   training_iteration: 1866
#   trial_id: 43c5c_00000
#   warmup_time: 0.003575563430786133
#
# == Status ==
# Current time: 2023-02-11 17:12:45 (running for 03:06:22.35)
# Memory usage on this node: 4.8/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# ...

# %%
# !nvidia-smi
# Out:
# Sat Feb 11 17:26:11 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0    51W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import torch

# %%
torch.__version__
# Out:
# '1.13.1+cu116'
