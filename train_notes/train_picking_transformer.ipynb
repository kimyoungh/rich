# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd drive/MyDrive/rich/main/rich/
# Out:
# /content/drive/MyDrive/rich/main/rich

# %%
# !pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install ray
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !PYTHONPATH=./ python trainers/picking_transformer_train.py --epoch_size=2000 --num_samples 1\
 --batch_size 256 --valid_batch_size 64 --device cuda --lr 0.001 --model_name picking_transformer
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Result for train_trader_1c9fb_00000:
#   date: 2023-02-05_18-01-21
#   done: false
#   experiment_id: 91d3227ac34d45ac83fc1e4d79038adf
#   hostname: 50c7eaa03a11
#   iterations_since_restore: 1866
#   loss: 1.4995944339978067
#   loss_max: 3.358416882941597
#   loss_prets: 0.3592280149459839
#   node_ip: 172.28.0.12
#   pid: 581377
#   should_checkpoint: true
#   time_since_restore: 10298.089960813522
#   time_this_iter_s: 5.534334182739258
#   time_total_s: 10298.089960813522
#   timestamp: 1675620081
#   timesteps_since_restore: 0
#   training_iteration: 1866
#   trial_id: 1c9fb_00000
#   warmup_time: 0.004018068313598633
#
# == Status ==
# Current time: 2023-02-05 18:01:26 (running for 02:51:46.45)
# Memory usage on this node: 5.1/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# ...

# %%
# !nvidia-smi
# Out:
# Sun Feb  5 18:13:52 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   29C    P0    48W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import torch

# %%
torch.__version__
# Out:
# '1.13.1+cu116'
