# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/rich/main/rich/
# Out:
# /content/drive/MyDrive/rich/main/rich

# %%
# !pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorboardX
#   Downloading tensorboardX-2.6-py2.py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 12.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorboardX) (23.0)
# Requirement already satisfied: protobuf<4,>=3.8.0 in /usr/local/lib/python3.9/dist-packages (from tensorboardX) (3.20.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from tensorboardX) (1.22.4)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.6

# %%
# !pip install ray
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ray
#   Downloading ray-2.3.1-cp39-cp39-manylinux2014_x86_64.whl (58.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.6/58.6 MB 17.9 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.9/dist-packages (from ray) (4.3.3)
# Requirement already satisfied: grpcio>=1.32.0 in /usr/local/lib/python3.9/dist-packages (from ray) (1.53.0)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.9/dist-packages (from ray) (1.22.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from ray) (3.11.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from ray) (1.0.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from ray) (2.27.1)
# Collecting aiosignal
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.9/dist-packages (from ray) (3.20.3)
# Collecting frozenlist
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 23.8 MB/s eta 0:00:00
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.9/dist-packages (from ray) (8.1.3)
# Collecting virtualenv>=20.0.24
#   Downloading virtualenv-20.21.0-py3-none-any.whl (8.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 106.3 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from ray) (6.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.9/dist-packages (from ray) (22.2.0)
# Collecting distlib<1,>=0.3.6
#   Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.5/468.5 kB 46.1 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs<4,>=2.4 in /usr/local/lib/python3.9/dist-packages (from virtualenv>=20.0.24->ray) (3.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema->ray) (0.19.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->ray) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->ray) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->ray) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->ray) (1.26.15)
# Installing collected packages: distlib, virtualenv, frozenlist, aiosignal, ray
# Successfully installed aiosignal-1.3.1 distlib-0.3.6 frozenlist-1.3.3 ray-2.3.1 virtualenv-20.21.0

# %%
# !PYTHONPATH=./ python trainers/trading_gpt_train_tf.py --epoch_size=100 --num_samples 1\
 --batch_size 256 --valid_batch_size 64 --device cuda --lr 0.00001 --model_tf_name trading_gpt_tf_rec2
# Out:
# 2023-04-15 13:37:44,640	INFO worker.py:1553 -- Started a local Ray instance.
# == Status ==
# Current time: 2023-04-15 13:37:49 (running for 00:00:03.50)
# Memory usage on this node: 2.9/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: None | Iter 1.000: None
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.86 GiB heap, 0.0/24.93 GiB objects (0.0/1.0 accelerator_type:A100)
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_gpt_tf_rec2/trading_gpt_tf_rec2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+
# | Trial name               | status   | loc              |
# |--------------------------+----------+------------------|
# | train_trader_b4724_00000 | RUNNING  | 172.28.0.12:7479 |
# +--------------------------+----------+------------------+
#
#
# == Status ==
# Current time: 2023-04-15 13:37:54 (running for 00:00:08.50)
# Memory usage on this node: 4.0/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: None | Iter 1.000: None
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.86 GiB heap, 0.0/24.93 GiB objects (0.0/1.0 accelerator_type:A100)
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_gpt_tf_rec2/trading_gpt_tf_rec2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+
# | Trial name               | status   | loc              |
# |--------------------------+----------+------------------|
# | train_trader_b4724_00000 | RUNNING  | 172.28.0.12:7479 |
# +--------------------------+----------+------------------+
#
#
# == Status ==
# Current time: 2023-04-15 13:37:59 (running for 00:00:13.52)
# Memory usage on this node: 4.5/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: None | Iter 1.000: None
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.86 GiB heap, 0.0/24.93 GiB objects (0.0/1.0 accelerator_type:A100)
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_gpt_tf_rec2/trading_gpt_tf_rec2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+
# | Trial name               | status   | loc              |
# |--------------------------+----------+------------------|
# | train_trader_b4724_00000 | RUNNING  | 172.28.0.12:7479 |
# +--------------------------+----------+------------------+
#
#
# (train_trader pid=7479) /usr/local/lib/python3.9/dist-packages/torch/nn/modules/transformer.py:544: UserWarning: Converting mask without torch.bool dtype to bool; this will negatively affect performance. Prefer to use a boolean mask directly. (Triggered internally at ../aten/src/ATen/native/transformers/attention.cpp:150.)
# (train_trader pid=7479)   return torch._transformer_encoder_layer_fwd(
# == Status ==
# Current time: 2023-04-15 13:38:04 (running for 00:00:18.52)
# Memory usage on this node: 4.9/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: None | Iter 1.000: None
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.86 GiB heap, 0.0/24.93 GiB objects (0.0/1.0 accelerator_type:A100)
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_gpt_tf_rec2/trading_gpt_tf_rec2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+
# | Trial name               | status   | loc              |
# |--------------------------+----------+------------------|
# | train_trader_b4724_00000 | RUNNING  | 172.28.0.12:7479 |
# +--------------------------+----------+------------------+
#
#
# Result for train_trader_b4724_00000:
#   date: 2023-04-15_13-38-07
#   done: false
#   experiment_id: b0e2c0a0c8a94d41b6fab846c68983da
#   hostname: 9488c6b42c73
#   iterations_since_restore: 1
#   loss: 1.3862798690795897
#   loss_k: 0.0009336585249911878
#   loss_r: -0.6931375861167908
#   node_ip: 172.28.0.12
#   pid: 7479
#   should_checkpoint: true
#   time_since_restore: 17.72404718399048
#   time_this_iter_s: 17.72404718399048
#   time_total_s: 17.72404718399048
#   timestamp: 1681565887
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: b4724_00000
#   warmup_time: 0.004611492156982422
#
# == Status ==
# Current time: 2023-04-15 13:38:12 (running for 00:00:26.28)
# Memory usage on this node: 4.9/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: None | Iter 1.000: -1.3862798690795897
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.86 GiB heap, 0.0/24.93 GiB objects (0.0/1.0 accelerator_type:A100)
# Current best trial: b4724_00000 with loss=1.3862798690795897 and parameters={'factor_num': 8, 'd_model': 32, 'dim_ff': 32, 'obs_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.2, 'nhead': 8, 'nlayers': 8, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KODEX 200'}, 'reward_embeds_nlayers': 1, 'action_map_nlayers': 1, 'reward_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_sl_name': 'trading_gpt_sl', 'model_tf_name': 'trading_gpt_tf_rec2', 'best_sl_model_path': '/content/drive/MyDrive/rich/main/rich/trained/trading_gpt_tf_rec/trading_gpt_tf_rec_best.pt', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_gpt/test_dataset_k200_2.pkl', 'epoch_size': 100, 'batch_size': 256, 'train_num_workers': 8, 'lr': 1e-05, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 64, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'T_0': 10, 'T_mult': 1, 'num_workers': 2, 'asset_idx': 0, 'trading_period': 60, 'trading_fee': 0.01, 'alpha': 2.0, 'beta': 0.005, 'iteration': 10}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_gpt_tf_rec2/trading_gpt_tf_rec2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+-------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |    loss |    loss_r |      loss_k |
# |--------------------------+----------+------------------+--------+------------------+---------+-----------+-------------|
# | train_trader_b4724_00000 | RUNNING  | 172.28.0.12:7479 |      1 |           17.724 | 1.38628 | -0.693138 | 0.000933659 |
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+-------------+
#
#
# Result for train_trader_b4724_00000:
#   date: 2023-04-15_13-38-13
#   done: false
#   experiment_id: b0e2c0a0c8a94d41b6fab846c68983da
#   hostname: 9488c6b42c73
#   iterations_since_restore: 2
#   loss: 1.3862864017486574
#   loss_k: 0.0021013422176110906
#   loss_r: -0.6931379437446594
#   node_ip: 172.28.0.12
#   pid: 7479
#   should_checkpoint: true
#   time_since_restore: 24.296769380569458
#   time_this_iter_s: 6.5727221965789795
#   time_total_s: 24.296769380569458
#   timestamp: 1681565893
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: b4724_00000
#   warmup_time: 0.004611492156982422
#
# == Status ==
# Current time: 2023-04-15 13:38:18 (running for 00:00:32.81)
# Memory usage on this node: 5.0/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: None | Iter 1.000: -1.3862798690795897
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.86 GiB heap, 0.0/24.93 GiB objects (0.0/1.0 accelerator_type:A100)
# Current best trial: b4724_00000 with loss=1.3862864017486574 and parameters={'factor_num': 8, 'd_model': 32, 'dim_ff': 32, 'obs_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.2, 'nhead': 8, 'nlayers': 8, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KODEX 200'}, 'reward_embeds_nlayers': 1, 'action_map_nlayers': 1, 'reward_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_sl_name': 'trading_gpt_sl', 'model_tf_name': 'trading_gpt_tf_rec2', 'best_sl_model_path': '/content/drive/MyDrive/rich/main/rich/trained/trading_gpt_tf_rec/trading_gpt_tf_rec_best.pt', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_gpt/test_dataset_k200_2.pkl', 'epoch_size': 100, 'batch_size': 256, 'train_num_workers': 8, 'lr': 1e-05, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 64, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'T_0': 10, 'T_mult': 1, 'num_workers': 2, 'asset_idx': 0, 'trading_period': 60, 'trading_fee': 0.01, 'alpha': 2.0, 'beta': 0.005, 'iteration': 10}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_gpt_tf_rec2/trading_gpt_tf_rec2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |    loss |    loss_r |     loss_k |
# |--------------------------+----------+------------------+--------+------------------+---------+-----------+------------|
# | train_trader_b4724_00000 | RUNNING  | 172.28.0.12:7479 |      2 |          24.2968 | 1.38629 | -0.693138 | 0.00210134 |
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
#
#
# Result for train_trader_b4724_00000:
#   date: 2023-04-15_13-38-20
#   done: false
#   experiment_id: b0e2c0a0c8a94d41b6fab846c68983da
#   hostname: 9488c6b42c73
#   iterations_since_restore: 3
#   loss: 1.3862462520599363
#   loss_k: 0.0033424613895476794
#   loss_r: -0.6931147694587707
#   node_ip: 172.28.0.12
#   pid: 7479
#   should_checkpoint: true
#   time_since_restore: 30.817914247512817
#   time_this_iter_s: 6.521144866943359
#   time_total_s: 30.817914247512817
#   timestamp: 1681565900
#   timesteps_since_restore: 0
#   training_iteration: 3
#   trial_id: b4724_00000
#   warmup_time: 0.004611492156982422
#
# == Status ==
# Current time: 2023-04-15 13:38:25 (running for 00:00:39.35)
# Memory usage on this node: 5.0/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: None | Iter 1.000: -1.3862798690795897
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.86 GiB heap, 0.0/24.93 GiB objects (0.0/1.0 accelerator_type:A100)
# Current best trial: b4724_00000 with loss=1.3862462520599363 and parameters={'factor_num': 8, 'd_model': 32, 'dim_ff': 32, 'obs_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.2, 'nhead': 8, 'nlayers': 8, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KODEX 200'}, 'reward_embeds_nlayers': 1, 'action_map_nlayers': 1, 'reward_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_sl_name': 'trading_gpt_sl', 'model_tf_name': 'trading_gpt_tf_rec2', 'best_sl_model_path': '/content/drive/MyDrive/rich/main/rich/trained/trading_gpt_tf_rec/trading_gpt_tf_rec_best.pt', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_gpt/test_dataset_k200_2.pkl', 'epoch_size': 100, 'batch_size': 256, 'train_num_workers': 8, 'lr': 1e-05, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 64, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'T_0': 10, 'T_mult': 1, 'num_workers': 2, 'asset_idx': 0, 'trading_period': 60, 'trading_fee': 0.01, 'alpha': 2.0, 'beta': 0.005, 'iteration': 10}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_gpt_tf_rec2/trading_gpt_tf_rec2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |    loss |    loss_r |     loss_k |
# |--------------------------+----------+------------------+--------+------------------+---------+-----------+------------|
# | train_trader_b4724_00000 | RUNNING  | 172.28.0.12:7479 |      3 |          30.8179 | 1.38625 | -0.693115 | 0.00334246 |
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
#
#
# Result for train_trader_b4724_00000:
#   date: 2023-04-15_13-38-26
#   done: false
#   experiment_id: b0e2c0a0c8a94d41b6fab846c68983da
#   hostname: 9488c6b42c73
#   iterations_since_restore: 4
#   loss: 1.386275577545166
#   loss_k: 0.0037502191800740546
#   loss_r: -0.6931284070014954
#   node_ip: 172.28.0.12
#   pid: 7479
#   should_checkpoint: true
#   time_since_restore: 37.36042022705078
#   time_this_iter_s: 6.542505979537964
#   time_total_s: 37.36042022705078
#   timestamp: 1681565906
#   timesteps_since_restore: 0
#   training_iteration: 4
#   trial_id: b4724_00000
#   warmup_time: 0.004611492156982422
#
# == Status ==
# Current time: 2023-04-15 13:38:31 (running for 00:00:45.87)
# Memory usage on this node: 5.0/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: -1.386275577545166 | Iter 1.000: -1.3862798690795897
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.86 GiB heap, 0.0/24.93 GiB objects (0.0/1.0 accelerator_type:A100)
# Current best trial: b4724_00000 with loss=1.386275577545166 and parameters={'factor_num': 8, 'd_model': 32, 'dim_ff': 32, 'obs_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.2, 'nhead': 8, 'nlayers': 8, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KODEX 200'}, 'reward_embeds_nlayers': 1, 'action_map_nlayers': 1, 'reward_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_sl_name': 'trading_gpt_sl', 'model_tf_name': 'trading_gpt_tf_rec2', 'best_sl_model_path': '/content/drive/MyDrive/rich/main/rich/trained/trading_gpt_tf_rec/trading_gpt_tf_rec_best.pt', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_gpt/test_dataset_k200_2.pkl', 'epoch_size': 100, 'batch_size': 256, 'train_num_workers': 8, 'lr': 1e-05, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 64, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'T_0': 10, 'T_mult': 1, 'num_workers': 2, 'asset_idx': 0, 'trading_period': 60, 'trading_fee': 0.01, 'alpha': 2.0, 'beta': 0.005, 'iteration': 10}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_gpt_tf_rec2/trading_gpt_tf_rec2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |    loss |    loss_r |     loss_k |
# |--------------------------+----------+------------------+--------+------------------+---------+-----------+------------|
# | train_trader_b4724_00000 | RUNNING  | 172.28.0.12:7479 |      4 |          37.3604 | 1.38628 | -0.693128 | 0.00375022 |
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
#
#
# Result for train_trader_b4724_00000:
#   date: 2023-04-15_13-38-33
#   done: false
#   experiment_id: b0e2c0a0c8a94d41b6fab846c68983da
#   hostname: 9488c6b42c73
#   iterations_since_restore: 5
#   loss: 1.3862677335739135
#   loss_k: 0.007394214579835535
#   loss_r: -0.6931153774261474
#   node_ip: 172.28.0.12
#   pid: 7479
#   should_checkpoint: true
#   time_since_restore: 43.93258547782898
#   time_this_iter_s: 6.572165250778198
#   time_total_s: 43.93258547782898
#   timestamp: 1681565913
#   timesteps_since_restore: 0
#   training_iteration: 5
#   trial_id: b4724_00000
#   warmup_time: 0.004611492156982422
#
# == Status ==
# Current time: 2023-04-15 13:38:38 (running for 00:00:52.47)
# Memory usage on this node: 5.0/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: -1.386275577545166 | Iter 1.000: -1.3862798690795897
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.86 GiB heap, 0.0/24.93 GiB objects (0.0/1.0 accelerator_type:A100)
# Current best trial: b4724_00000 with loss=1.3862677335739135 and parameters={'factor_num': 8, 'd_model': 32, 'dim_ff': 32, 'obs_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.2, 'nhead': 8, 'nlayers': 8, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KODEX 200'}, 'reward_embeds_nlayers': 1, 'action_map_nlayers': 1, 'reward_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_sl_name': 'trading_gpt_sl', 'model_tf_name': 'trading_gpt_tf_rec2', 'best_sl_model_path': '/content/drive/MyDrive/rich/main/rich/trained/trading_gpt_tf_rec/trading_gpt_tf_rec_best.pt', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_gpt/test_dataset_k200_2.pkl', 'epoch_size': 100, 'batch_size': 256, 'train_num_workers': 8, 'lr': 1e-05, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 64, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'T_0': 10, 'T_mult': 1, 'num_workers': 2, 'asset_idx': 0, 'trading_period': 60, 'trading_fee': 0.01, 'alpha': 2.0, 'beta': 0.005, 'iteration': 10}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_gpt_tf_rec2/trading_gpt_tf_rec2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |    loss |    loss_r |     loss_k |
# |--------------------------+----------+------------------+--------+------------------+---------+-----------+------------|
# | train_trader_b4724_00000 | RUNNING  | 172.28.0.12:7479 |      5 |          43.9326 | 1.38627 | -0.693115 | 0.00739421 |
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
#
#
# Result for train_trader_b4724_00000:
#   date: 2023-04-15_13-38-39
#   done: false
#   experiment_id: b0e2c0a0c8a94d41b6fab846c68983da
#   hostname: 9488c6b42c73
#   iterations_since_restore: 6
#   loss: 1.3863694429397584
#   loss_k: 0.008050314662978054
#   loss_r: -0.6931645870208739
#   node_ip: 172.28.0.12
#   pid: 7479
#   should_checkpoint: true
#   time_since_restore: 50.50154709815979
#   time_this_iter_s: 6.5689616203308105
#   time_total_s: 50.50154709815979
#   timestamp: 1681565919
#   timesteps_since_restore: 0
#   training_iteration: 6
#   trial_id: b4724_00000
#   warmup_time: 0.004611492156982422
#
# == Status ==
# Current time: 2023-04-15 13:38:44 (running for 00:00:59.02)
# Memory usage on this node: 5.0/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: -1.386275577545166 | Iter 1.000: -1.3862798690795897
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.86 GiB heap, 0.0/24.93 GiB objects (0.0/1.0 accelerator_type:A100)
# Current best trial: b4724_00000 with loss=1.3863694429397584 and parameters={'factor_num': 8, 'd_model': 32, 'dim_ff': 32, 'obs_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.2, 'nhead': 8, 'nlayers': 8, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KODEX 200'}, 'reward_embeds_nlayers': 1, 'action_map_nlayers': 1, 'reward_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_sl_name': 'trading_gpt_sl', 'model_tf_name': 'trading_gpt_tf_rec2', 'best_sl_model_path': '/content/drive/MyDrive/rich/main/rich/trained/trading_gpt_tf_rec/trading_gpt_tf_rec_best.pt', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_gpt/test_dataset_k200_2.pkl', 'epoch_size': 100, 'batch_size': 256, 'train_num_workers': 8, 'lr': 1e-05, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 64, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'T_0': 10, 'T_mult': 1, 'num_workers': 2, 'asset_idx': 0, 'trading_period': 60, 'trading_fee': 0.01, 'alpha': 2.0, 'beta': 0.005, 'iteration': 10}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_gpt_tf_rec2/trading_gpt_tf_rec2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |    loss |    loss_r |     loss_k |
# |--------------------------+----------+------------------+--------+------------------+---------+-----------+------------|
# | train_trader_b4724_00000 | RUNNING  | 172.28.0.12:7479 |      6 |          50.5015 | 1.38637 | -0.693165 | 0.00805031 |
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
#
#
# Result for train_trader_b4724_00000:
#   date: 2023-04-15_13-38-46
#   done: false
#   experiment_id: b0e2c0a0c8a94d41b6fab846c68983da
#   hostname: 9488c6b42c73
#   iterations_since_restore: 7
#   loss: 1.3862736463546754
#   loss_k: 0.009461367735639215
#   loss_r: -0.6931131839752197
#   node_ip: 172.28.0.12
#   pid: 7479
#   should_checkpoint: true
#   time_since_restore: 57.07052707672119
#   time_this_iter_s: 6.568979978561401
#   time_total_s: 57.07052707672119
#   timestamp: 1681565926
#   timesteps_since_restore: 0
#   training_iteration: 7
#   trial_id: b4724_00000
#   warmup_time: 0.004611492156982422
#
# == Status ==
# Current time: 2023-04-15 13:38:51 (running for 00:01:05.60)
# Memory usage on this node: 5.0/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: -1.386275577545166 | Iter 1.000: -1.3862798690795897
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.86 GiB heap, 0.0/24.93 GiB objects (0.0/1.0 accelerator_type:A100)
# Current best trial: b4724_00000 with loss=1.3862736463546754 and parameters={'factor_num': 8, 'd_model': 32, 'dim_ff': 32, 'obs_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.2, 'nhead': 8, 'nlayers': 8, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KODEX 200'}, 'reward_embeds_nlayers': 1, 'action_map_nlayers': 1, 'reward_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_sl_name': 'trading_gpt_sl', 'model_tf_name': 'trading_gpt_tf_rec2', 'best_sl_model_path': '/content/drive/MyDrive/rich/main/rich/trained/trading_gpt_tf_rec/trading_gpt_tf_rec_best.pt', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_gpt/test_dataset_k200_2.pkl', 'epoch_size': 100, 'batch_size': 256, 'train_num_workers': 8, 'lr': 1e-05, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 64, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'T_0': 10, 'T_mult': 1, 'num_workers': 2, 'asset_idx': 0, 'trading_period': 60, 'trading_fee': 0.01, 'alpha': 2.0, 'beta': 0.005, 'iteration': 10}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_gpt_tf_rec2/trading_gpt_tf_rec2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |    loss |    loss_r |     loss_k |
# |--------------------------+----------+------------------+--------+------------------+---------+-----------+------------|
# | train_trader_b4724_00000 | RUNNING  | 172.28.0.12:7479 |      7 |          57.0705 | 1.38627 | -0.693113 | 0.00946137 |
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
#
#
# Result for train_trader_b4724_00000:
#   date: 2023-04-15_13-38-53
#   done: false
#   experiment_id: b0e2c0a0c8a94d41b6fab846c68983da
#   hostname: 9488c6b42c73
#   iterations_since_restore: 8
#   loss: 1.386366081237793
#   loss_k: 0.007099904748611151
#   loss_r: -0.6931652903556824
#   node_ip: 172.28.0.12
#   pid: 7479
#   should_checkpoint: true
#   time_since_restore: 63.64331293106079
#   time_this_iter_s: 6.5727858543396
#   time_total_s: 63.64331293106079
#   timestamp: 1681565933
#   timesteps_since_restore: 0
#   training_iteration: 8
#   trial_id: b4724_00000
#   warmup_time: 0.004611492156982422
#
# == Status ==
# Current time: 2023-04-15 13:38:58 (running for 00:01:12.16)
# Memory usage on this node: 5.0/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: -1.386275577545166 | Iter 1.000: -1.3862798690795897
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.86 GiB heap, 0.0/24.93 GiB objects (0.0/1.0 accelerator_type:A100)
# Current best trial: b4724_00000 with loss=1.386366081237793 and parameters={'factor_num': 8, 'd_model': 32, 'dim_ff': 32, 'obs_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.2, 'nhead': 8, 'nlayers': 8, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KODEX 200'}, 'reward_embeds_nlayers': 1, 'action_map_nlayers': 1, 'reward_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_sl_name': 'trading_gpt_sl', 'model_tf_name': 'trading_gpt_tf_rec2', 'best_sl_model_path': '/content/drive/MyDrive/rich/main/rich/trained/trading_gpt_tf_rec/trading_gpt_tf_rec_best.pt', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_gpt/test_dataset_k200_2.pkl', 'epoch_size': 100, 'batch_size': 256, 'train_num_workers': 8, 'lr': 1e-05, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 64, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'T_0': 10, 'T_mult': 1, 'num_workers': 2, 'asset_idx': 0, 'trading_period': 60, 'trading_fee': 0.01, 'alpha': 2.0, 'beta': 0.005, 'iteration': 10}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_gpt_tf_rec2/trading_gpt_tf_rec2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+-----------+
# | Trial name               | status   | loc              |   iter |   total time (s) |    loss |    loss_r |    loss_k |
# |--------------------------+----------+------------------+--------+------------------+---------+-----------+-----------|
# | train_trader_b4724_00000 | RUNNING  | 172.28.0.12:7479 |      8 |          63.6433 | 1.38637 | -0.693165 | 0.0070999 |
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+-----------+
#
#
# Result for train_trader_b4724_00000:
#   date: 2023-04-15_13-38-59
#   done: false
#   experiment_id: b0e2c0a0c8a94d41b6fab846c68983da
#   hostname: 9488c6b42c73
#   iterations_since_restore: 9
#   loss: 1.3862831830978395
#   loss_k: 0.007107319426722825
#   loss_r: -0.6931238174438477
#   node_ip: 172.28.0.12
#   pid: 7479
#   should_checkpoint: true
#   time_since_restore: 70.14452314376831
#   time_this_iter_s: 6.5012102127075195
#   time_total_s: 70.14452314376831
#   timestamp: 1681565939
#   timesteps_since_restore: 0
#   training_iteration: 9
#   trial_id: b4724_00000
#   warmup_time: 0.004611492156982422
#
# == Status ==
# Current time: 2023-04-15 13:39:04 (running for 00:01:18.68)
# Memory usage on this node: 5.0/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: -1.386275577545166 | Iter 1.000: -1.3862798690795897
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.86 GiB heap, 0.0/24.93 GiB objects (0.0/1.0 accelerator_type:A100)
# Current best trial: b4724_00000 with loss=1.3862831830978395 and parameters={'factor_num': 8, 'd_model': 32, 'dim_ff': 32, 'obs_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.2, 'nhead': 8, 'nlayers': 8, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KODEX 200'}, 'reward_embeds_nlayers': 1, 'action_map_nlayers': 1, 'reward_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_sl_name': 'trading_gpt_sl', 'model_tf_name': 'trading_gpt_tf_rec2', 'best_sl_model_path': '/content/drive/MyDrive/rich/main/rich/trained/trading_gpt_tf_rec/trading_gpt_tf_rec_best.pt', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_gpt/test_dataset_k200_2.pkl', 'epoch_size': 100, 'batch_size': 256, 'train_num_workers': 8, 'lr': 1e-05, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 64, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'T_0': 10, 'T_mult': 1, 'num_workers': 2, 'asset_idx': 0, 'trading_period': 60, 'trading_fee': 0.01, 'alpha': 2.0, 'beta': 0.005, 'iteration': 10}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_gpt_tf_rec2/trading_gpt_tf_rec2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |    loss |    loss_r |     loss_k |
# |--------------------------+----------+------------------+--------+------------------+---------+-----------+------------|
# | train_trader_b4724_00000 | RUNNING  | 172.28.0.12:7479 |      9 |          70.1445 | 1.38628 | -0.693124 | 0.00710732 |
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
#
#
# Result for train_trader_b4724_00000:
#   date: 2023-04-15_13-39-06
#   done: false
#   experiment_id: b0e2c0a0c8a94d41b6fab846c68983da
#   hostname: 9488c6b42c73
#   iterations_since_restore: 10
#   loss: 1.3862966060638426
#   loss_k: 0.007569404505193233
#   loss_r: -0.6931293845176696
#   node_ip: 172.28.0.12
#   pid: 7479
#   should_checkpoint: true
#   time_since_restore: 76.69821739196777
#   time_this_iter_s: 6.553694248199463
#   time_total_s: 76.69821739196777
#   timestamp: 1681565946
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: b4724_00000
#   warmup_time: 0.004611492156982422
#
# == Status ==
# Current time: 2023-04-15 13:39:11 (running for 00:01:25.21)
# Memory usage on this node: 5.0/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: -1.386275577545166 | Iter 1.000: -1.3862798690795897
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.86 GiB heap, 0.0/24.93 GiB objects (0.0/1.0 accelerator_type:A100)
# Current best trial: b4724_00000 with loss=1.3862966060638426 and parameters={'factor_num': 8, 'd_model': 32, 'dim_ff': 32, 'obs_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.2, 'nhead': 8, 'nlayers': 8, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KODEX 200'}, 'reward_embeds_nlayers': 1, 'action_map_nlayers': 1, 'reward_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_sl_name': 'trading_gpt_sl', 'model_tf_name': 'trading_gpt_tf_rec2', 'best_sl_model_path': '/content/drive/MyDrive/rich/main/rich/trained/trading_gpt_tf_rec/trading_gpt_tf_rec_best.pt', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_gpt/test_dataset_k200_2.pkl', 'epoch_size': 100, 'batch_size': 256, 'train_num_workers': 8, 'lr': 1e-05, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 64, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'T_0': 10, 'T_mult': 1, 'num_workers': 2, 'asset_idx': 0, 'trading_period': 60, 'trading_fee': 0.01, 'alpha': 2.0, 'beta': 0.005, 'iteration': 10}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_gpt_tf_rec2/trading_gpt_tf_rec2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+--------+-----------+-----------+
# | Trial name               | status   | loc              |   iter |   total time (s) |   loss |    loss_r |    loss_k |
# |--------------------------+----------+------------------+--------+------------------+--------+-----------+-----------|
# | train_trader_b4724_00000 | RUNNING  | 172.28.0.12:7479 |     10 |          76.6982 | 1.3863 | -0.693129 | 0.0075694 |
# +--------------------------+----------+------------------+--------+------------------+--------+-----------+-----------+
#
#
# Result for train_trader_b4724_00000:
#   date: 2023-04-15_13-39-12
#   done: false
#   experiment_id: b0e2c0a0c8a94d41b6fab846c68983da
#   hostname: 9488c6b42c73
#   iterations_since_restore: 11
#   loss: 1.3862289190292358
#   loss_k: 0.012153011746704578
#   loss_r: -0.6930840849876404
#   node_ip: 172.28.0.12
#   pid: 7479
#   should_checkpoint: true
#   time_since_restore: 83.24330878257751
#   time_this_iter_s: 6.545091390609741
#   time_total_s: 83.24330878257751
#   timestamp: 1681565952
#   timesteps_since_restore: 0
#   training_iteration: 11
#   trial_id: b4724_00000
#   warmup_time: 0.004611492156982422
#
# == Status ==
# Current time: 2023-04-15 13:39:17 (running for 00:01:31.78)
# Memory usage on this node: 5.0/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: -1.386275577545166 | Iter 1.000: -1.3862798690795897
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.86 GiB heap, 0.0/24.93 GiB objects (0.0/1.0 accelerator_type:A100)
# Current best trial: b4724_00000 with loss=1.3862289190292358 and parameters={'factor_num': 8, 'd_model': 32, 'dim_ff': 32, 'obs_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.2, 'nhead': 8, 'nlayers': 8, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KODEX 200'}, 'reward_embeds_nlayers': 1, 'action_map_nlayers': 1, 'reward_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_sl_name': 'trading_gpt_sl', 'model_tf_name': 'trading_gpt_tf_rec2', 'best_sl_model_path': '/content/drive/MyDrive/rich/main/rich/trained/trading_gpt_tf_rec/trading_gpt_tf_rec_best.pt', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_gpt/test_dataset_k200_2.pkl', 'epoch_size': 100, 'batch_size': 256, 'train_num_workers': 8, 'lr': 1e-05, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 64, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'T_0': 10, 'T_mult': 1, 'num_workers': 2, 'asset_idx': 0, 'trading_period': 60, 'trading_fee': 0.01, 'alpha': 2.0, 'beta': 0.005, 'iteration': 10}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_gpt_tf_rec2/trading_gpt_tf_rec2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+----------+
# | Trial name               | status   | loc              |   iter |   total time (s) |    loss |    loss_r |   loss_k |
# |--------------------------+----------+------------------+--------+------------------+---------+-----------+----------|
# | train_trader_b4724_00000 | RUNNING  | 172.28.0.12:7479 |     11 |          83.2433 | 1.38623 | -0.693084 | 0.012153 |
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+----------+
#
#
# Result for train_trader_b4724_00000:
#   date: 2023-04-15_13-39-19
#   done: false
#   experiment_id: b0e2c0a0c8a94d41b6fab846c68983da
#   hostname: 9488c6b42c73
#   iterations_since_restore: 12
#   loss: 1.38630633354187
#   loss_k: 0.0008822995993796211
#   loss_r: -0.6931509613990783
#   node_ip: 172.28.0.12
#   pid: 7479
#   should_checkpoint: true
#   time_since_restore: 89.79894399642944
#   time_this_iter_s: 6.555635213851929
#   time_total_s: 89.79894399642944
#   timestamp: 1681565959
#   timesteps_since_restore: 0
#   training_iteration: 12
#   trial_id: b4724_00000
#   warmup_time: 0.004611492156982422
#
# == Status ==
# Current time: 2023-04-15 13:39:24 (running for 00:01:38.31)
# Memory usage on this node: 5.0/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: -1.386275577545166 | Iter 1.000: -1.3862798690795897
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.86 GiB heap, 0.0/24.93 GiB objects (0.0/1.0 accelerator_type:A100)
# Current best trial: b4724_00000 with loss=1.38630633354187 and parameters={'factor_num': 8, 'd_model': 32, 'dim_ff': 32, 'obs_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.2, 'nhead': 8, 'nlayers': 8, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KODEX 200'}, 'reward_embeds_nlayers': 1, 'action_map_nlayers': 1, 'reward_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_sl_name': 'trading_gpt_sl', 'model_tf_name': 'trading_gpt_tf_rec2', 'best_sl_model_path': '/content/drive/MyDrive/rich/main/rich/trained/trading_gpt_tf_rec/trading_gpt_tf_rec_best.pt', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_gpt/test_dataset_k200_2.pkl', 'epoch_size': 100, 'batch_size': 256, 'train_num_workers': 8, 'lr': 1e-05, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 64, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'T_0': 10, 'T_mult': 1, 'num_workers': 2, 'asset_idx': 0, 'trading_period': 60, 'trading_fee': 0.01, 'alpha': 2.0, 'beta': 0.005, 'iteration': 10}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_gpt_tf_rec2/trading_gpt_tf_rec2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+-----------+
# | Trial name               | status   | loc              |   iter |   total time (s) |    loss |    loss_r |    loss_k |
# |--------------------------+----------+------------------+--------+------------------+---------+-----------+-----------|
# | train_trader_b4724_00000 | RUNNING  | 172.28.0.12:7479 |     12 |          89.7989 | 1.38631 | -0.693151 | 0.0008823 |
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+-----------+
#
#
# Result for train_trader_b4724_00000:
#   date: 2023-04-15_13-39-25
#   done: false
#   experiment_id: b0e2c0a0c8a94d41b6fab846c68983da
#   hostname: 9488c6b42c73
#   iterations_since_restore: 13
#   loss: 1.3863391637802123
#   loss_k: 0.004934640853025485
#   loss_r: -0.6931572556495667
#   node_ip: 172.28.0.12
#   pid: 7479
#   should_checkpoint: true
#   time_since_restore: 96.3071460723877
#   time_this_iter_s: 6.508202075958252
#   time_total_s: 96.3071460723877
#   timestamp: 1681565965
#   timesteps_since_restore: 0
#   training_iteration: 13
#   trial_id: b4724_00000
#   warmup_time: 0.004611492156982422
#
# == Status ==
# Current time: 2023-04-15 13:39:30 (running for 00:01:44.85)
# Memory usage on this node: 5.0/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: -1.386275577545166 | Iter 1.000: -1.3862798690795897
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.86 GiB heap, 0.0/24.93 GiB objects (0.0/1.0 accelerator_type:A100)
# Current best trial: b4724_00000 with loss=1.3863391637802123 and parameters={'factor_num': 8, 'd_model': 32, 'dim_ff': 32, 'obs_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.2, 'nhead': 8, 'nlayers': 8, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KODEX 200'}, 'reward_embeds_nlayers': 1, 'action_map_nlayers': 1, 'reward_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_sl_name': 'trading_gpt_sl', 'model_tf_name': 'trading_gpt_tf_rec2', 'best_sl_model_path': '/content/drive/MyDrive/rich/main/rich/trained/trading_gpt_tf_rec/trading_gpt_tf_rec_best.pt', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_gpt/test_dataset_k200_2.pkl', 'epoch_size': 100, 'batch_size': 256, 'train_num_workers': 8, 'lr': 1e-05, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 64, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'T_0': 10, 'T_mult': 1, 'num_workers': 2, 'asset_idx': 0, 'trading_period': 60, 'trading_fee': 0.01, 'alpha': 2.0, 'beta': 0.005, 'iteration': 10}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_gpt_tf_rec2/trading_gpt_tf_rec2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |    loss |    loss_r |     loss_k |
# |--------------------------+----------+------------------+--------+------------------+---------+-----------+------------|
# | train_trader_b4724_00000 | RUNNING  | 172.28.0.12:7479 |     13 |          96.3071 | 1.38634 | -0.693157 | 0.00493464 |
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+------------+
#
#
# Result for train_trader_b4724_00000:
#   date: 2023-04-15_13-39-32
#   done: false
#   experiment_id: b0e2c0a0c8a94d41b6fab846c68983da
#   hostname: 9488c6b42c73
#   iterations_since_restore: 14
#   loss: 1.386373496055603
#   loss_k: 0.010154927056282759
#   loss_r: -0.6931613564491272
#   node_ip: 172.28.0.12
#   pid: 7479
#   should_checkpoint: true
#   time_since_restore: 102.85724759101868
#   time_this_iter_s: 6.5501015186309814
#   time_total_s: 102.85724759101868
#   timestamp: 1681565972
#   timesteps_since_restore: 0
#   training_iteration: 14
#   trial_id: b4724_00000
#   warmup_time: 0.004611492156982422
#
# == Status ==
# Current time: 2023-04-15 13:39:37 (running for 00:01:51.37)
# Memory usage on this node: 5.0/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: -1.386275577545166 | Iter 1.000: -1.3862798690795897
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.86 GiB heap, 0.0/24.93 GiB objects (0.0/1.0 accelerator_type:A100)
# Current best trial: b4724_00000 with loss=1.386373496055603 and parameters={'factor_num': 8, 'd_model': 32, 'dim_ff': 32, 'obs_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.2, 'nhead': 8, 'nlayers': 8, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KODEX 200'}, 'reward_embeds_nlayers': 1, 'action_map_nlayers': 1, 'reward_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_sl_name': 'trading_gpt_sl', 'model_tf_name': 'trading_gpt_tf_rec2', 'best_sl_model_path': '/content/drive/MyDrive/rich/main/rich/trained/trading_gpt_tf_rec/trading_gpt_tf_rec_best.pt', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_gpt/test_dataset_k200_2.pkl', 'epoch_size': 100, 'batch_size': 256, 'train_num_workers': 8, 'lr': 1e-05, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 64, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'T_0': 10, 'T_mult': 1, 'num_workers': 2, 'asset_idx': 0, 'trading_period': 60, 'trading_fee': 0.01, 'alpha': 2.0, 'beta': 0.005, 'iteration': 10}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_gpt_tf_rec2/trading_gpt_tf_rec2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+-----------+
# | Trial name               | status   | loc              |   iter |   total time (s) |    loss |    loss_r |    loss_k |
# |--------------------------+----------+------------------+--------+------------------+---------+-----------+-----------|
# | train_trader_b4724_00000 | RUNNING  | 172.28.0.12:7479 |     14 |          102.857 | 1.38637 | -0.693161 | 0.0101549 |
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+-----------+
#
#
# Result for train_trader_b4724_00000:
#   date: 2023-04-15_13-39-38
#   done: false
#   experiment_id: b0e2c0a0c8a94d41b6fab846c68983da
#   hostname: 9488c6b42c73
#   iterations_since_restore: 15
#   loss: 1.3863702297210694
#   loss_k: 0.012071832630317659
#   loss_r: -0.6931549310684203
#   node_ip: 172.28.0.12
#   pid: 7479
#   should_checkpoint: true
#   time_since_restore: 109.37529683113098
#   time_this_iter_s: 6.518049240112305
#   time_total_s: 109.37529683113098
#   timestamp: 1681565978
#   timesteps_since_restore: 0
#   training_iteration: 15
#   trial_id: b4724_00000
#   warmup_time: 0.004611492156982422
#
# == Status ==
# Current time: 2023-04-15 13:39:43 (running for 00:01:57.91)
# Memory usage on this node: 5.0/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: -1.386275577545166 | Iter 1.000: -1.3862798690795897
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.86 GiB heap, 0.0/24.93 GiB objects (0.0/1.0 accelerator_type:A100)
# Current best trial: b4724_00000 with loss=1.3863702297210694 and parameters={'factor_num': 8, 'd_model': 32, 'dim_ff': 32, 'obs_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.2, 'nhead': 8, 'nlayers': 8, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KODEX 200'}, 'reward_embeds_nlayers': 1, 'action_map_nlayers': 1, 'reward_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_sl_name': 'trading_gpt_sl', 'model_tf_name': 'trading_gpt_tf_rec2', 'best_sl_model_path': '/content/drive/MyDrive/rich/main/rich/trained/trading_gpt_tf_rec/trading_gpt_tf_rec_best.pt', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_gpt/test_dataset_k200_2.pkl', 'epoch_size': 100, 'batch_size': 256, 'train_num_workers': 8, 'lr': 1e-05, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 64, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'T_0': 10, 'T_mult': 1, 'num_workers': 2, 'asset_idx': 0, 'trading_period': 60, 'trading_fee': 0.01, 'alpha': 2.0, 'beta': 0.005, 'iteration': 10}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_gpt_tf_rec2/trading_gpt_tf_rec2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+-----------+
# | Trial name               | status   | loc              |   iter |   total time (s) |    loss |    loss_r |    loss_k |
# |--------------------------+----------+------------------+--------+------------------+---------+-----------+-----------|
# | train_trader_b4724_00000 | RUNNING  | 172.28.0.12:7479 |     15 |          109.375 | 1.38637 | -0.693155 | 0.0120718 |
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+-----------+
#
#
# Result for train_trader_b4724_00000:
#   date: 2023-04-15_13-39-45
#   done: false
#   experiment_id: b0e2c0a0c8a94d41b6fab846c68983da
#   hostname: 9488c6b42c73
#   iterations_since_restore: 16
#   loss: 1.3863360166549683
#   loss_k: 0.012586665619164706
#   loss_r: -0.6931365489959718
#   node_ip: 172.28.0.12
#   pid: 7479
#   should_checkpoint: true
#   time_since_restore: 115.9274640083313
#   time_this_iter_s: 6.552167177200317
#   time_total_s: 115.9274640083313
# ...
#   pid: 7479
#   should_checkpoint: true
#   time_since_restore: 639.5887701511383
#   time_this_iter_s: 6.567088842391968
#   time_total_s: 639.5887701511383
#   timestamp: 1681566508
#   timesteps_since_restore: 0
#   training_iteration: 96
#   trial_id: b4724_00000
#   warmup_time: 0.004611492156982422
#
# == Status ==
# Current time: 2023-04-15 13:48:33 (running for 00:10:48.10)
# Memory usage on this node: 5.0/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 64.000: -1.3862857818603516 | Iter 16.000: -1.3863360166549683 | Iter 4.000: -1.386275577545166 | Iter 1.000: -1.3862798690795897
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.86 GiB heap, 0.0/24.93 GiB objects (0.0/1.0 accelerator_type:A100)
# Current best trial: b4724_00000 with loss=1.3862797021865847 and parameters={'factor_num': 8, 'd_model': 32, 'dim_ff': 32, 'obs_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.2, 'nhead': 8, 'nlayers': 8, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KODEX 200'}, 'reward_embeds_nlayers': 1, 'action_map_nlayers': 1, 'reward_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_sl_name': 'trading_gpt_sl', 'model_tf_name': 'trading_gpt_tf_rec2', 'best_sl_model_path': '/content/drive/MyDrive/rich/main/rich/trained/trading_gpt_tf_rec/trading_gpt_tf_rec_best.pt', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_gpt/test_dataset_k200_2.pkl', 'epoch_size': 100, 'batch_size': 256, 'train_num_workers': 8, 'lr': 1e-05, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 64, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'T_0': 10, 'T_mult': 1, 'num_workers': 2, 'asset_idx': 0, 'trading_period': 60, 'trading_fee': 0.01, 'alpha': 2.0, 'beta': 0.005, 'iteration': 10}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_gpt_tf_rec2/trading_gpt_tf_rec2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+-------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |    loss |    loss_r |      loss_k |
# |--------------------------+----------+------------------+--------+------------------+---------+-----------+-------------|
# | train_trader_b4724_00000 | RUNNING  | 172.28.0.12:7479 |     96 |          639.589 | 1.38628 | -0.693138 | 0.000558551 |
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+-------------+
#
#
# Result for train_trader_b4724_00000:
#   date: 2023-04-15_13-48-35
#   done: false
#   experiment_id: b0e2c0a0c8a94d41b6fab846c68983da
#   hostname: 9488c6b42c73
#   iterations_since_restore: 97
#   loss: 1.3863066911697388
#   loss_k: 0.0006283116352278739
#   loss_r: -0.6931517720222473
#   node_ip: 172.28.0.12
#   pid: 7479
#   should_checkpoint: true
#   time_since_restore: 646.125746011734
#   time_this_iter_s: 6.536975860595703
#   time_total_s: 646.125746011734
#   timestamp: 1681566515
#   timesteps_since_restore: 0
#   training_iteration: 97
#   trial_id: b4724_00000
#   warmup_time: 0.004611492156982422
#
# == Status ==
# Current time: 2023-04-15 13:48:40 (running for 00:10:54.69)
# Memory usage on this node: 5.0/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 64.000: -1.3862857818603516 | Iter 16.000: -1.3863360166549683 | Iter 4.000: -1.386275577545166 | Iter 1.000: -1.3862798690795897
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.86 GiB heap, 0.0/24.93 GiB objects (0.0/1.0 accelerator_type:A100)
# Current best trial: b4724_00000 with loss=1.3863066911697388 and parameters={'factor_num': 8, 'd_model': 32, 'dim_ff': 32, 'obs_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.2, 'nhead': 8, 'nlayers': 8, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KODEX 200'}, 'reward_embeds_nlayers': 1, 'action_map_nlayers': 1, 'reward_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_sl_name': 'trading_gpt_sl', 'model_tf_name': 'trading_gpt_tf_rec2', 'best_sl_model_path': '/content/drive/MyDrive/rich/main/rich/trained/trading_gpt_tf_rec/trading_gpt_tf_rec_best.pt', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_gpt/test_dataset_k200_2.pkl', 'epoch_size': 100, 'batch_size': 256, 'train_num_workers': 8, 'lr': 1e-05, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 64, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'T_0': 10, 'T_mult': 1, 'num_workers': 2, 'asset_idx': 0, 'trading_period': 60, 'trading_fee': 0.01, 'alpha': 2.0, 'beta': 0.005, 'iteration': 10}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_gpt_tf_rec2/trading_gpt_tf_rec2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+-------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |    loss |    loss_r |      loss_k |
# |--------------------------+----------+------------------+--------+------------------+---------+-----------+-------------|
# | train_trader_b4724_00000 | RUNNING  | 172.28.0.12:7479 |     97 |          646.126 | 1.38631 | -0.693152 | 0.000628312 |
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+-------------+
#
#
# Result for train_trader_b4724_00000:
#   date: 2023-04-15_13-48-42
#   done: false
#   experiment_id: b0e2c0a0c8a94d41b6fab846c68983da
#   hostname: 9488c6b42c73
#   iterations_since_restore: 98
#   loss: 1.3862964153289794
#   loss_k: 0.0005129865174239967
#   loss_r: -0.6931469321250915
#   node_ip: 172.28.0.12
#   pid: 7479
#   should_checkpoint: true
#   time_since_restore: 652.6411240100861
#   time_this_iter_s: 6.515377998352051
#   time_total_s: 652.6411240100861
#   timestamp: 1681566522
#   timesteps_since_restore: 0
#   training_iteration: 98
#   trial_id: b4724_00000
#   warmup_time: 0.004611492156982422
#
# == Status ==
# Current time: 2023-04-15 13:48:47 (running for 00:11:01.16)
# Memory usage on this node: 5.0/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 64.000: -1.3862857818603516 | Iter 16.000: -1.3863360166549683 | Iter 4.000: -1.386275577545166 | Iter 1.000: -1.3862798690795897
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.86 GiB heap, 0.0/24.93 GiB objects (0.0/1.0 accelerator_type:A100)
# Current best trial: b4724_00000 with loss=1.3862964153289794 and parameters={'factor_num': 8, 'd_model': 32, 'dim_ff': 32, 'obs_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.2, 'nhead': 8, 'nlayers': 8, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KODEX 200'}, 'reward_embeds_nlayers': 1, 'action_map_nlayers': 1, 'reward_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_sl_name': 'trading_gpt_sl', 'model_tf_name': 'trading_gpt_tf_rec2', 'best_sl_model_path': '/content/drive/MyDrive/rich/main/rich/trained/trading_gpt_tf_rec/trading_gpt_tf_rec_best.pt', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_gpt/test_dataset_k200_2.pkl', 'epoch_size': 100, 'batch_size': 256, 'train_num_workers': 8, 'lr': 1e-05, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 64, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'T_0': 10, 'T_mult': 1, 'num_workers': 2, 'asset_idx': 0, 'trading_period': 60, 'trading_fee': 0.01, 'alpha': 2.0, 'beta': 0.005, 'iteration': 10}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_gpt_tf_rec2/trading_gpt_tf_rec2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+--------+-----------+-------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |   loss |    loss_r |      loss_k |
# |--------------------------+----------+------------------+--------+------------------+--------+-----------+-------------|
# | train_trader_b4724_00000 | RUNNING  | 172.28.0.12:7479 |     98 |          652.641 | 1.3863 | -0.693147 | 0.000512987 |
# +--------------------------+----------+------------------+--------+------------------+--------+-----------+-------------+
#
#
# Result for train_trader_b4724_00000:
#   date: 2023-04-15_13-48-48
#   done: false
#   experiment_id: b0e2c0a0c8a94d41b6fab846c68983da
#   hostname: 9488c6b42c73
#   iterations_since_restore: 99
#   loss: 1.3863099336624145
#   loss_k: 0.0008309774246299639
#   loss_r: -0.693152904510498
#   node_ip: 172.28.0.12
#   pid: 7479
#   should_checkpoint: true
#   time_since_restore: 659.2221214771271
#   time_this_iter_s: 6.580997467041016
#   time_total_s: 659.2221214771271
#   timestamp: 1681566528
#   timesteps_since_restore: 0
#   training_iteration: 99
#   trial_id: b4724_00000
#   warmup_time: 0.004611492156982422
#
# == Status ==
# Current time: 2023-04-15 13:48:53 (running for 00:11:07.78)
# Memory usage on this node: 5.0/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 64.000: -1.3862857818603516 | Iter 16.000: -1.3863360166549683 | Iter 4.000: -1.386275577545166 | Iter 1.000: -1.3862798690795897
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.86 GiB heap, 0.0/24.93 GiB objects (0.0/1.0 accelerator_type:A100)
# Current best trial: b4724_00000 with loss=1.3863099336624145 and parameters={'factor_num': 8, 'd_model': 32, 'dim_ff': 32, 'obs_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.2, 'nhead': 8, 'nlayers': 8, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KODEX 200'}, 'reward_embeds_nlayers': 1, 'action_map_nlayers': 1, 'reward_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_sl_name': 'trading_gpt_sl', 'model_tf_name': 'trading_gpt_tf_rec2', 'best_sl_model_path': '/content/drive/MyDrive/rich/main/rich/trained/trading_gpt_tf_rec/trading_gpt_tf_rec_best.pt', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_gpt/test_dataset_k200_2.pkl', 'epoch_size': 100, 'batch_size': 256, 'train_num_workers': 8, 'lr': 1e-05, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 64, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'T_0': 10, 'T_mult': 1, 'num_workers': 2, 'asset_idx': 0, 'trading_period': 60, 'trading_fee': 0.01, 'alpha': 2.0, 'beta': 0.005, 'iteration': 10}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_gpt_tf_rec2/trading_gpt_tf_rec2
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+-------------+
# | Trial name               | status   | loc              |   iter |   total time (s) |    loss |    loss_r |      loss_k |
# |--------------------------+----------+------------------+--------+------------------+---------+-----------+-------------|
# | train_trader_b4724_00000 | RUNNING  | 172.28.0.12:7479 |     99 |          659.222 | 1.38631 | -0.693153 | 0.000830977 |
# +--------------------------+----------+------------------+--------+------------------+---------+-----------+-------------+
#
#
# Result for train_trader_b4724_00000:
#   date: 2023-04-15_13-48-55
#   done: true
#   experiment_id: b0e2c0a0c8a94d41b6fab846c68983da
#   hostname: 9488c6b42c73
#   iterations_since_restore: 100
#   loss: 1.3862704753875732
#   loss_k: 0.0009379403723869473
#   loss_r: -0.6931328892707824
#   node_ip: 172.28.0.12
#   pid: 7479
#   should_checkpoint: true
#   time_since_restore: 665.752748966217
#   time_this_iter_s: 6.530627489089966
#   time_total_s: 665.752748966217
#   timestamp: 1681566535
#   timesteps_since_restore: 0
#   training_iteration: 100
#   trial_id: b4724_00000
#   warmup_time: 0.004611492156982422
#
# Trial train_trader_b4724_00000 completed.
# == Status ==
# Current time: 2023-04-15 13:48:55 (running for 00:11:09.34)
# Memory usage on this node: 3.6/83.5 GiB
# Using AsyncHyperBand: num_stopped=1
# Bracket: Iter 64.000: -1.3862857818603516 | Iter 16.000: -1.3863360166549683 | Iter 4.000: -1.386275577545166 | Iter 1.000: -1.3862798690795897
# Resources requested: 0/8 CPUs, 0/1 GPUs, 0.0/49.86 GiB heap, 0.0/24.93 GiB objects (0.0/1.0 accelerator_type:A100)
# Current best trial: b4724_00000 with loss=1.3862704753875732 and parameters={'factor_num': 8, 'd_model': 32, 'dim_ff': 32, 'obs_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.2, 'nhead': 8, 'nlayers': 8, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KODEX 200'}, 'reward_embeds_nlayers': 1, 'action_map_nlayers': 1, 'reward_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_sl_name': 'trading_gpt_sl', 'model_tf_name': 'trading_gpt_tf_rec2', 'best_sl_model_path': '/content/drive/MyDrive/rich/main/rich/trained/trading_gpt_tf_rec/trading_gpt_tf_rec_best.pt', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_gpt/test_dataset_k200_2.pkl', 'epoch_size': 100, 'batch_size': 256, 'train_num_workers': 8, 'lr': 1e-05, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 64, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'T_0': 10, 'T_mult': 1, 'num_workers': 2, 'asset_idx': 0, 'trading_period': 60, 'trading_fee': 0.01, 'alpha': 2.0, 'beta': 0.005, 'iteration': 10}
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_gpt_tf_rec2/trading_gpt_tf_rec2
# Number of trials: 1/1 (1 TERMINATED)
# +--------------------------+------------+------------------+--------+------------------+---------+-----------+------------+
# | Trial name               | status     | loc              |   iter |   total time (s) |    loss |    loss_r |     loss_k |
# |--------------------------+------------+------------------+--------+------------------+---------+-----------+------------|
# | train_trader_b4724_00000 | TERMINATED | 172.28.0.12:7479 |    100 |          665.753 | 1.38627 | -0.693133 | 0.00093794 |
# +--------------------------+------------+------------------+--------+------------------+---------+-----------+------------+
#
#
# 2023-04-15 13:48:55,203	INFO tune.py:798 -- Total run time: 669.47 seconds (669.27 seconds for the tuning loop).
# Best config is:  {'factor_num': 8, 'd_model': 32, 'dim_ff': 32, 'obs_map_nlayers': 1, 'slope': 0.2, 'dropout': 0.2, 'nhead': 8, 'nlayers': 8, 'activation': 'gelu', 'max_len': 5000, 'actions': tensor([0, 1]), 'assets': {0: 'KODEX 200'}, 'reward_embeds_nlayers': 1, 'action_map_nlayers': 1, 'reward_map_nlayers': 1, 'load_model': False, 'load_model_path': None, 'model_path': '/content/drive/MyDrive/rich/main/rich/trained/', 'model_sl_name': 'trading_gpt_sl', 'model_tf_name': 'trading_gpt_tf_rec2', 'best_sl_model_path': '/content/drive/MyDrive/rich/main/rich/trained/trading_gpt_tf_rec/trading_gpt_tf_rec_best.pt', 'checkpoint_dir': './ray_checkpoints/', 'datasets_path': '/content/drive/MyDrive/rich/main/rich/train_data/trading_gpt/test_dataset_k200_2.pkl', 'epoch_size': 100, 'batch_size': 256, 'train_num_workers': 8, 'lr': 1e-05, 'amsgrad': True, 'beta_1': 0.9, 'beta_2': 0.999, 'valid_batch_size': 64, 'valid_prob': 0.3, 'num_samples': 1, 'device': 'cuda', 'num_gpu': 1, 'lr_scheduling': False, 'T_0': 10, 'T_mult': 1, 'num_workers': 2, 'asset_idx': 0, 'trading_period': 60, 'trading_fee': 0.01, 'alpha': 2.0, 'beta': 0.005, 'iteration': 10}
# /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_gpt_tf_rec2/trading_gpt_tf_rec2/train_trader_b4724_00000_0_2023-04-15_13-37-46

# %%
# !nvidia-smi
# Out:
# Mon Apr 10 14:04:54 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    54W / 400W |      0MiB / 40960MiB |      1%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import torch

# %%
torch.__version__
# Out:
# '2.0.0+cu118'
