# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd drive/MyDrive/rich/main/rich/
# Out:
# /content/drive/MyDrive/rich/main/rich

# %%
# !pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install ray[tune]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !PYTHONPATH=./ python trainers/ipa_train.py --epoch_size=3333 --num_samples 5 --lr_scheduling --sched_term 500\
  --lr 0.001 --batch_size 128 --valid_batch_size 128
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# | train_ipa_b1df6_00001 | TERMINATED | 172.28.0.2:2157817 |      1 |          1.50341 | 4.03411 |
# +-----------------------+------------+--------------------+--------+------------------+---------+
#
#
# Result for train_ipa_b1df6_00002:
#   date: 2022-10-02_07-05-03
#   done: false
#   experiment_id: 25caec482ad243f7b49004e33dc1a20b
#   hostname: 8c6a9be6c3c5
#   iterations_since_restore: 2837
#   loss: 1.6875008219764347
#   node_ip: 172.28.0.2
#   pid: 2157817
#   should_checkpoint: true
#   time_since_restore: 4120.779781103134
#   time_this_iter_s: 1.407418966293335
#   time_total_s: 4120.779781103134
#   timestamp: 1664694303
#   timesteps_since_restore: 0
#   training_iteration: 2837
#   trial_id: b1df6_00002
#   warmup_time: 0.004050731658935547
#
# == Status ==
# Current time: 2022-10-02 07:05:06 (running for 02:29:14.53)
# Memory usage on this node: 3.3/51.0 GiB
# Using AsyncHyperBand: num_stopped=2
# ...

# %%
# !nvidia-smi
# Out:
# Sun Oct  2 07:17:36 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    41W / 300W |      0MiB / 16160MiB |     16%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import torch

# %%
torch.__version__
# Out:
# '1.12.1+cu113'
