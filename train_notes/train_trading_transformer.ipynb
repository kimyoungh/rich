# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd drive/MyDrive/rich/main/rich/
# Out:
# /content/drive/MyDrive/rich/main/rich

# %%
# !pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install ray
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !PYTHONPATH=./ python trainers/trading_transformer_train.py --epoch_size=1000 --num_samples 1\
 --batch_size 512 --valid_batch_size 512 --device cuda --lr 0.001 --model_name trading_transformer_2
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   time_total_s: 747.9282975196838
#   timestamp: 1670144725
#   timesteps_since_restore: 0
#   training_iteration: 485
#   trial_id: 0a88c_00000
#   warmup_time: 0.005008220672607422
#
# == Status ==
# Current time: 2022-12-04 09:05:25 (running for 00:12:31.00)
# Memory usage on this node: 4.0/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 256.000: -17.489236695669323 | Iter 64.000: -16.719145052598947 | Iter 16.000: -27.23623809152312 | Iter 4.000: -174.48415730622781 | Iter 1.000: -247.85204249240275
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.66 GiB heap, 0.0/24.83 GiB objects
# ...

# %%
# !nvidia-smi
# Out:
# Sun Dec  4 09:19:05 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-SXM4-40GB      Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   29C    P0    54W / 400W |      0MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import torch

# %%
torch.__version__
# Out:
# '1.12.1+cu113'
