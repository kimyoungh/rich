# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/rich/main/rich/
# Out:
# /content/drive/MyDrive/rich/main/rich

# %%
# !pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 125 kB 26.6 MB/s
# ...

# %%
# !pip install ray
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 57.4 MB 1.1 MB/s
# ...
#      |████████████████████████████████| 8.8 MB 76.9 MB/s
# ...
#      |████████████████████████████████| 468 kB 70.4 MB/s
# ...

# %%
# !PYTHONPATH=./ python trainers/trading_bc_transformer_train.py --epoch_size=1000 --num_samples 1\
 --batch_size 2048 --valid_batch_size 2048 --device cuda --lr 0.001 --model_name trading_bc_transformer_10
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Result logdir: /content/drive/MyDrive/rich/main/rich/ray_checkpoints/trading_bc_transformer_10/trading_bc_transformer_10
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------+----------+------------------+--------+------------------+---------+
# | Trial name               | status   | loc              |   iter |   total time (s) |    loss |
# |--------------------------+----------+------------------+--------+------------------+---------|
# | train_trader_f22bb_00000 | RUNNING  | 172.28.0.12:2440 |     96 |          87.9097 | 1.32151 |
# +--------------------------+----------+------------------+--------+------------------+---------+
#
#
# Result for train_trader_f22bb_00000:
#   date: 2023-01-03_14-37-38
#   done: false
#   experiment_id: 7659abdc5a8846a6a0d64d8703251528
#   hostname: ad121e5ac393
#   iterations_since_restore: 102
#   loss: 1.3150641073783238
#   node_ip: 172.28.0.12
#   pid: 2440
#   should_checkpoint: true
# ...

# %%
# !nvidia-smi
# Out:
# Tue Jan  3 14:50:26 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-SXM4-40GB      Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0    50W / 400W |      0MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import torch

# %%
torch.__version__
# Out:
# '1.13.0+cu116'
