# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd drive/MyDrive/rich/main/rich/
# Out:
# /content/drive/MyDrive/rich/main/rich

# %%
# !pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install ray
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !PYTHONPATH=./ python trainers/trading_gpt_train_sl.py --epoch_size=1000 --num_samples 1\
 --batch_size 256 --valid_batch_size 64 --device cuda --lr 0.001
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Memory usage on this node: 5.0/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 256.000: -0.19030643999576569 | Iter 64.000: -0.481900064434324 | Iter 16.000: -0.6826953138623918 | Iter 4.000: -0.6901469009263175 | Iter 1.000: -0.6919647301946367
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.87 GiB heap, 0.0/24.94 GiB objects (0.0/1.0 accelerator_type:A100)
# ...

# %%
# !nvidia-smi

# %%
import torch

# %%
torch.__version__
