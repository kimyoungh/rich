# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/rich/main/rich/
# Out:
# /content/drive/MyDrive/rich/main/rich

# %%
# !pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 KB 4.2 MB/s eta 0:00:00
# ...

# %%
# !pip install ray
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 MB 31.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 119.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.5/468.5 KB 52.8 MB/s eta 0:00:00
# ...

# %%
# !PYTHONPATH=./ python trainers/trading_bc_transformer2_train.py --epoch_size=10000 --pretrain_epoch_prob=0.5 --num_samples 1\
 --batch_size 2048 --valid_batch_size 512 --device cuda --lr 0.0001 --model_name trading_bc_transformer2_k200\
 --k200
# Out:
# Streaming output truncated to the last 5000 lines.
#   pid: 3612
#   should_checkpoint: true
#   time_since_restore: 11153.04227590561
#   time_this_iter_s: 1.255211353302002
#   time_total_s: 11153.04227590561
#   timestamp: 1674503372
#   timesteps_since_restore: 0
#   training_iteration: 9389
#   trial_id: 14e3d_00000
#   warmup_time: 0.004143953323364258
#
# == Status ==
# Current time: 2023-01-23 19:49:32 (running for 03:05:56.02)
# Memory usage on this node: 5.4/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4096.000: -0.5401158863455496 | Iter 1024.000: -1.4587431784909133 | Iter 256.000: -1.713832844839498 | Iter 64.000: -1.7078340769412783 | Iter 16.000: -1.820019066252559 | Iter 4.000: -2.40479030105217 | Iter 1.000: -2.4690214177154823
# Resources requested: 8.0/8 CPUs, 1.0/1 GPUs, 0.0/49.87 GiB heap, 0.0/24.94 GiB objects
# ...

# %%
# !nvidia-smi
# Out:
# Mon Jan 16 13:11:42 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-SXM4-40GB      Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0    52W / 400W |      0MiB / 40536MiB |      7%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import torch

# %%
torch.__version__
# Out:
# '1.13.0+cu116'
