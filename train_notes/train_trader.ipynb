# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd drive/MyDrive/rich/main/rich/
# Out:
# /content/drive/MyDrive/rich/main/rich

# %%
# !pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install ray[tune]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !PYTHONPATH=./ python trainers/trader_train.py --epoch_size=1000 --num_samples 1\
 --batch_size 128 --valid_batch_size 128 --device cuda --lr 0.001 --lr_scheduling --sched_term 10 --lr_decay 0.9
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Result for train_trader_0ea8d_00000:
#   date: 2022-11-13_05-02-47
#   done: false
#   experiment_id: 77d949b221634dc6963aba5a6f616f76
#   hostname: 29cb955d73d4
#   iterations_since_restore: 733
#   loss: 0.15199431980561962
#   loss_s: 0.0058303577939245975
#   loss_w: 0.30981899740516394
#   node_ip: 172.28.0.2
#   pid: 291762
#   should_checkpoint: true
#   time_since_restore: 2727.984450817108
#   time_this_iter_s: 3.794473648071289
#   time_total_s: 2727.984450817108
#   timestamp: 1668315767
#   timesteps_since_restore: 0
#   training_iteration: 733
#   trial_id: 0ea8d_00000
#   warmup_time: 0.0037200450897216797
#
# == Status ==
# Current time: 2022-11-13 05:02:51 (running for 00:45:34.57)
# Memory usage on this node: 5.0/83.5 GiB
# Using AsyncHyperBand: num_stopped=0
# ...

# %%
# !nvidia-smi
# Out:
# Sun Nov 13 05:19:35 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-SXM4-40GB      Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0    48W / 400W |      0MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import torch

# %%
torch.__version__
# Out:
# '1.12.1+cu113'
